# %% [markdown]
# <a href="https://colab.research.google.com/github/Offliners/writeup/blob/main/HW10/homework10-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Homework 10 - Adversarial Attack**
#
# Slides: https://reurl.cc/v5kXkk
#
# Videos:
#
# TA: ntu-ml-2021spring-ta@googlegroups.com

# %% [markdown]
# ## Enviroment & Download
#
# We make use of [pytorchcv](https://pypi.org/project/pytorchcv/) to obtain CIFAR-10 pretrained model, so we need to set up the enviroment first. We also need to download the data (200 images) which we want to attack.

# %%
# set up environment
# !pip install pytorchcv

# download
# !gdown --id 1fHi1ko7wr80wXkXpqpqpOxuYH1mClXoX -O data.zip

# unzip
# !unzip ./data.zip
# !rm ./data.zip
# Out:
# Collecting pytorchcv
#   Downloading https://files.pythonhosted.org/packages/44/74/e5dae0875679d296fa9a3833041699cee9222e2d3dd1f9ae1ded050b5672/pytorchcv-0.0.65-py2.py3-none-any.whl (527kB)
#      |████████████████████████████████| 532kB 7.1MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from pytorchcv) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pytorchcv) (1.19.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->pytorchcv) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->pytorchcv) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->pytorchcv) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->pytorchcv) (1.24.3)
# Installing collected packages: pytorchcv
# Successfully installed pytorchcv-0.0.65
# Downloading...
# From: https://drive.google.com/uc?id=1fHi1ko7wr80wXkXpqpqpOxuYH1mClXoX
# To: /content/data.zip
# 100% 490k/490k [00:00<00:00, 66.7MB/s]
# Archive:  ./data.zip
#    creating: data/
#    creating: data/deer/
#  extracting: data/deer/deer13.png
#  extracting: data/deer/deer6.png
#  extracting: data/deer/deer11.png
#  extracting: data/deer/deer2.png
#  extracting: data/deer/deer10.png
#  extracting: data/deer/deer16.png
#  extracting: data/deer/deer9.png
#  extracting: data/deer/deer20.png
#  extracting: data/deer/deer15.png
#  extracting: data/deer/deer19.png
#  extracting: data/deer/deer5.png
#  extracting: data/deer/deer14.png
#  extracting: data/deer/deer4.png
#  extracting: data/deer/deer8.png
#  extracting: data/deer/deer12.png
#  extracting: data/deer/deer1.png
#  extracting: data/deer/deer7.png
#  extracting: data/deer/deer17.png
#  extracting: data/deer/deer18.png
#  extracting: data/deer/deer3.png
#    creating: data/horse/
#  extracting: data/horse/horse9.png
#  extracting: data/horse/horse1.png
#  extracting: data/horse/horse16.png
#  extracting: data/horse/horse15.png
#  extracting: data/horse/horse19.png
#  extracting: data/horse/horse14.png
#  extracting: data/horse/horse10.png
#  extracting: data/horse/horse7.png
#  extracting: data/horse/horse2.png
#  extracting: data/horse/horse6.png
#  extracting: data/horse/horse20.png
#  extracting: data/horse/horse5.png
#  extracting: data/horse/horse18.png
#  extracting: data/horse/horse12.png
#  extracting: data/horse/horse13.png
#  extracting: data/horse/horse17.png
#  extracting: data/horse/horse4.png
#  extracting: data/horse/horse11.png
#  extracting: data/horse/horse8.png
#  extracting: data/horse/horse3.png
#    creating: data/ship/
#  extracting: data/ship/ship10.png
#  extracting: data/ship/ship14.png
#  extracting: data/ship/ship9.png
#  extracting: data/ship/ship20.png
#  extracting: data/ship/ship5.png
#  extracting: data/ship/ship8.png
#  extracting: data/ship/ship19.png
#  extracting: data/ship/ship16.png
#  extracting: data/ship/ship13.png
#  extracting: data/ship/ship6.png
#  extracting: data/ship/ship17.png
#  extracting: data/ship/ship1.png
#  extracting: data/ship/ship12.png
#  extracting: data/ship/ship2.png
#  extracting: data/ship/ship3.png
#  extracting: data/ship/ship15.png
#  extracting: data/ship/ship4.png
#  extracting: data/ship/ship7.png
#  extracting: data/ship/ship11.png
#  extracting: data/ship/ship18.png
#    creating: data/frog/
#  extracting: data/frog/frog10.png
#  extracting: data/frog/frog4.png
#  extracting: data/frog/frog5.png
#  extracting: data/frog/frog20.png
#  extracting: data/frog/frog15.png
#  extracting: data/frog/frog3.png
#  extracting: data/frog/frog1.png
#  extracting: data/frog/frog14.png
#  extracting: data/frog/frog2.png
#  extracting: data/frog/frog19.png
#  extracting: data/frog/frog7.png
#  extracting: data/frog/frog11.png
#  extracting: data/frog/frog17.png
#  extracting: data/frog/frog18.png
#  extracting: data/frog/frog12.png
#  extracting: data/frog/frog16.png
#  extracting: data/frog/frog8.png
#  extracting: data/frog/frog13.png
#  extracting: data/frog/frog6.png
#  extracting: data/frog/frog9.png
#    creating: data/airplane/
#  extracting: data/airplane/airplane3.png
#  extracting: data/airplane/airplane4.png
#  extracting: data/airplane/airplane2.png
#  extracting: data/airplane/airplane9.png
#  extracting: data/airplane/airplane20.png
#  extracting: data/airplane/airplane18.png
#  extracting: data/airplane/airplane19.png
#  extracting: data/airplane/airplane10.png
#  extracting: data/airplane/airplane6.png
#  extracting: data/airplane/airplane13.png
#  extracting: data/airplane/airplane16.png
#  extracting: data/airplane/airplane14.png
#  extracting: data/airplane/airplane11.png
#  extracting: data/airplane/airplane1.png
#  extracting: data/airplane/airplane17.png
#  extracting: data/airplane/airplane7.png
#  extracting: data/airplane/airplane15.png
#  extracting: data/airplane/airplane5.png
#  extracting: data/airplane/airplane8.png
#  extracting: data/airplane/airplane12.png
#    creating: data/bird/
#  extracting: data/bird/bird9.png
#  extracting: data/bird/bird12.png
#  extracting: data/bird/bird10.png
#  extracting: data/bird/bird11.png
#  extracting: data/bird/bird5.png
#  extracting: data/bird/bird8.png
#  extracting: data/bird/bird4.png
#  extracting: data/bird/bird3.png
#  extracting: data/bird/bird7.png
#  extracting: data/bird/bird18.png
#  extracting: data/bird/bird14.png
#  extracting: data/bird/bird13.png
#  extracting: data/bird/bird2.png
#  extracting: data/bird/bird15.png
#  extracting: data/bird/bird17.png
#  extracting: data/bird/bird19.png
#  extracting: data/bird/bird16.png
#  extracting: data/bird/bird6.png
#  extracting: data/bird/bird20.png
#  extracting: data/bird/bird1.png
#    creating: data/cat/
#  extracting: data/cat/cat6.png
#  extracting: data/cat/cat1.png
#  extracting: data/cat/cat7.png
#  extracting: data/cat/cat19.png
#  extracting: data/cat/cat5.png
#  extracting: data/cat/cat9.png
#  extracting: data/cat/cat17.png
#  extracting: data/cat/cat2.png
#  extracting: data/cat/cat16.png
#  extracting: data/cat/cat10.png
#  extracting: data/cat/cat4.png
#  extracting: data/cat/cat18.png
#  extracting: data/cat/cat13.png
#  extracting: data/cat/cat11.png
#  extracting: data/cat/cat20.png
#  extracting: data/cat/cat15.png
#  extracting: data/cat/cat8.png
#  extracting: data/cat/cat14.png
#  extracting: data/cat/cat3.png
#  extracting: data/cat/cat12.png
#    creating: data/automobile/
#  extracting: data/automobile/automobile17.png
#  extracting: data/automobile/automobile11.png
#  extracting: data/automobile/automobile5.png
#  extracting: data/automobile/automobile10.png
#  extracting: data/automobile/automobile20.png
#  extracting: data/automobile/automobile2.png
#  extracting: data/automobile/automobile6.png
#  extracting: data/automobile/automobile1.png
#  extracting: data/automobile/automobile19.png
#  extracting: data/automobile/automobile7.png
#  extracting: data/automobile/automobile16.png
#  extracting: data/automobile/automobile3.png
#  extracting: data/automobile/automobile14.png
#  extracting: data/automobile/automobile12.png
#  extracting: data/automobile/automobile9.png
#  extracting: data/automobile/automobile4.png
#  extracting: data/automobile/automobile8.png
#  extracting: data/automobile/automobile13.png
#  extracting: data/automobile/automobile18.png
#  extracting: data/automobile/automobile15.png
#    creating: data/dog/
#  extracting: data/dog/dog9.png
#  extracting: data/dog/dog2.png
#  extracting: data/dog/dog15.png
#  extracting: data/dog/dog8.png
#  extracting: data/dog/dog3.png
#  extracting: data/dog/dog19.png
#  extracting: data/dog/dog12.png
#  extracting: data/dog/dog7.png
#  extracting: data/dog/dog17.png
#  extracting: data/dog/dog11.png
#  extracting: data/dog/dog16.png
#  extracting: data/dog/dog20.png
#  extracting: data/dog/dog4.png
#  extracting: data/dog/dog5.png
#  extracting: data/dog/dog14.png
#  extracting: data/dog/dog18.png
#  extracting: data/dog/dog10.png
#  extracting: data/dog/dog1.png
#  extracting: data/dog/dog13.png
#  extracting: data/dog/dog6.png
#    creating: data/truck/
#  extracting: data/truck/truck1.png
#  extracting: data/truck/truck18.png
#  extracting: data/truck/truck9.png
#  extracting: data/truck/truck4.png
#  extracting: data/truck/truck14.png
#  extracting: data/truck/truck8.png
#  extracting: data/truck/truck12.png
#  extracting: data/truck/truck15.png
#  extracting: data/truck/truck2.png
#  extracting: data/truck/truck5.png
#  extracting: data/truck/truck3.png
#  extracting: data/truck/truck10.png
#  extracting: data/truck/truck17.png
#  extracting: data/truck/truck20.png
#  extracting: data/truck/truck19.png
#  extracting: data/truck/truck13.png
#  extracting: data/truck/truck7.png
#  extracting: data/truck/truck6.png
#   inflating: data/truck/truck16.png
#  extracting: data/truck/truck11.png

# %% [markdown]
# ## Global Settings
#
# * $\epsilon$ is fixed to be 8. But on **Data section**, we will first apply transforms on raw pixel value (0-255 scale) **by ToTensor (to 0-1 scale)** and then **Normalize (subtract mean divide std)**. $\epsilon$ should be set to $\frac{8}{255 * std}$ during attack.
#
# * Explaination (optional)
#     * Denote the first pixel of original image as $p$, and the first pixel of adversarial image as $a$.
#     * The $\epsilon$ constraints tell us $\left| p-a \right| <= 8$.
#     * ToTensor() can be seen as a function where $T(x) = x/255$.
#     * Normalize() can be seen as a function where $N(x) = (x-mean)/std$ where $mean$ and $std$ are constants.
#     * After applying ToTensor() and Normalize() on $p$ and $a$, the constraint becomes $\left| N(T(p))-N(T(a)) \right| = \left| \frac{\frac{p}{255}-mean}{std}-\frac{\frac{a}{255}-mean}{std} \right| = \frac{1}{255 * std} \left| p-a \right| <= \frac{8}{255 * std}.$
#     * So, we should set $\epsilon$ to be $\frac{8}{255 * std}$ after ToTensor() and Normalize().

# %%
import torch
import torch.nn as nn

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

batch_size = 8

# the mean and std are the calculated statistics from cifar_10 dataset
cifar_10_mean = (0.491, 0.482, 0.447) # mean for the three channels of cifar_10 images
cifar_10_std = (0.202, 0.199, 0.201) # std for the three channels of cifar_10 images

# convert mean and std to 3-dimensional tensors for future operations
mean = torch.tensor(cifar_10_mean).to(device).view(3, 1, 1)
std = torch.tensor(cifar_10_std).to(device).view(3, 1, 1)

epsilon = 0.1 / std # 8/255/std
# TODO: iterative fgsm attack
# alpha (step size) can be decided by yourself
alpha = 0.5 / std # 8/255/std

root = './data' # directory for storing benign images
# benign images: images which do not contain adversarial perturbations
# adversarial images: images which include adversarial perturbations

# %% [markdown]
# ## Data
#
# Construct dataset and dataloader from root directory. Note that we store the filename of each image for future usage.

# %%
import os
import glob
import shutil
import numpy as np
from PIL import Image
from torchvision.transforms import transforms
from torch.utils.data import Dataset, DataLoader

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(cifar_10_mean, cifar_10_std)
])

class AdvDataset(Dataset):
    def __init__(self, data_dir, transform):
        self.images = []
        self.labels = []
        self.names = []
        '''
        data_dir
        ├── class_dir
        │   ├── class1.png
        │   ├── ...
        │   ├── class20.png
        '''
        for i, class_dir in enumerate(sorted(glob.glob(f'{data_dir}/*'))):
            images = sorted(glob.glob(f'{class_dir}/*'))
            self.images += images
            self.labels += ([i] * len(images))
            self.names += [os.path.relpath(imgs, data_dir) for imgs in images]
        self.transform = transform
    def __getitem__(self, idx):
        image = self.transform(Image.open(self.images[idx]))
        label = self.labels[idx]
        return image, label
    def __getname__(self):
        return self.names
    def __len__(self):
        return len(self.images)

adv_set = AdvDataset(root, transform=transform)
adv_names = adv_set.__getname__()
adv_loader = DataLoader(adv_set, batch_size=batch_size, shuffle=False)

print(f'number of images = {adv_set.__len__()}')
# Out:
# number of images = 200

# %% [markdown]
# ## Utils -- Benign Images Evaluation

# %%
# to evaluate the performance of model on benign images
def epoch_benign(model, loader, loss_fn):
    model.eval()
    train_acc, train_loss = 0.0, 0.0
    for x, y in loader:
        x, y = x.to(device), y.to(device)
        yp = model(x)
        loss = loss_fn(yp, y)
        train_acc += (yp.argmax(dim=1) == y).sum().item()
        train_loss += loss.item() * x.shape[0]
    return train_acc / len(loader.dataset), train_loss / len(loader.dataset)

# %% [markdown]
# ## Utils -- Attack Algorithm

# %%
# perform fgsm attack
def fgsm(model, x, y, loss_fn, epsilon=epsilon):
    x_adv = x.detach().clone() # initialize x_adv as original benign image x
    x_adv.requires_grad = True # need to obtain gradient of x_adv, thus set required grad
    loss = loss_fn(model(x_adv), y) # calculate loss
    loss.backward() # calculate gradient
    # fgsm: use gradient ascent on x_adv to maximize loss
    x_adv = x_adv + epsilon * x_adv.grad.detach().sign()
    return x_adv

# TODO: perform iterative fgsm attack
# set alpha as the step size in Global Settings section
# alpha and num_iter can be decided by yourself
def ifgsm(model, x, y, loss_fn, epsilon=epsilon, alpha=alpha, num_iter=20):
    # initialize x_adv as original benign image x
    x_adv = x.detach().clone()
    # write a loop of num_iter to represent the iterative times
    # for each loop
    for i in range(num_iter):
        # call fgsm with (epsilon = alpha) to obtain new x_adv
        x_adv = fgsm(model, x_adv, y, loss_fn, alpha)
        # clip new x_adv back to [x-epsilon, x+epsilon]
        x_adv = torch.max(torch.min(x_adv, x+epsilon), x-epsilon)
    return x_adv
    # pass

# %% [markdown]
# ## Utils -- Attack
#
# * Recall
#     * ToTensor() can be seen as a function where $T(x) = x/255$.
#     * Normalize() can be seen as a function where $N(x) = (x-mean)/std$ where $mean$ and $std$ are constants.
#
# * Inverse function
#     * Inverse Normalize() can be seen as a function where $N^{-1}(x) = x*std+mean$ where $mean$ and $std$ are constants.
#     * Inverse ToTensor() can be seen as a function where $T^{-1}(x) = x*255$.
#
# * Special Noted
#     * ToTensor() will also convert the image from shape (height, width, channel) to shape (channel, height, width), so we also need to transpose the shape back to original shape.
#     * Since our dataloader samples a batch of data, what we need here is to transpose **(batch_size, channel, height, width)** back to **(batch_size, height, width, channel)** using np.transpose.

# %%
# perform adversarial attack and generate adversarial examples
def gen_adv_examples(model, loader, attack, loss_fn):
    model.eval()
    adv_names = []
    train_acc = []
    train_loss = 0.0
    for i, (x, y) in enumerate(loader):
        x, y = x.to(device), y.to(device)
        x_adv = attack(model, x, y, loss_fn) # obtain adversarial examples
        yp = model(x_adv)
        loss = loss_fn(yp, y)
        train_acc.append((yp.argmax(dim=1) == y).sum().item())
        train_loss += loss.item() * x.shape[0]
        # store adversarial examples
        adv_ex = ((x_adv) * std + mean).clamp(0, 1) # to 0-1 scale
        adv_ex = (adv_ex * 255).clamp(0, 255) # 0-255 scale
        adv_ex = adv_ex.detach().cpu().data.numpy().round() # round to remove decimal part
        adv_ex = adv_ex.transpose((0, 2, 3, 1)) # transpose (bs, C, H, W) back to (bs, H, W, C)
        adv_examples = adv_ex if i == 0 else np.r_[adv_examples, adv_ex]
    return adv_examples, train_acc, train_loss / len(loader.dataset)

# create directory which stores adversarial examples
def create_dir(data_dir, adv_dir, adv_examples, adv_names):
    if os.path.exists(adv_dir) is not True:
        _ = shutil.copytree(data_dir, adv_dir)
    for example, name in zip(adv_examples, adv_names):
        im = Image.fromarray(example.astype(np.uint8)) # image pixel value should be unsigned int
        im.save(os.path.join(adv_dir, name))

# %% [markdown]
# ## Model / Loss Function
#
# Model list is available [here](https://github.com/osmr/imgclsmob/blob/master/pytorch/pytorchcv/model_provider.py). Please select models which has _cifar10 suffix. Some of the models cannot be accessed/loaded. You can safely skip them since TA's model will not use those kinds of models.

# %%
from pytorchcv.model_provider import get_model as ptcv_get_model

model1 = ptcv_get_model('resnet110_cifar10', pretrained=True).to(device)
model2 = ptcv_get_model('densenet100_k12_cifar10', pretrained=True).to(device)
model3 = ptcv_get_model('seresnet110_cifar10', pretrained=True).to(device)
model4 = ptcv_get_model('preresnet110_cifar10', pretrained=True).to(device)
model5 = ptcv_get_model('pyramidnet110_a270_cifar10', pretrained=True).to(device)

models = [model1, model2, model3, model4, model5]
loss_fn = nn.CrossEntropyLoss()

for model in models:
    benign_acc, benign_loss = epoch_benign(model, adv_loader, loss_fn)
    print(f'benign_acc = {benign_acc:.5f}, benign_loss = {benign_loss:.5f}')
# Out:
# benign_acc = 0.95000, benign_loss = 0.22678
# benign_acc = 0.96000, benign_loss = 0.28858
# benign_acc = 0.95500, benign_loss = 0.27532
# benign_acc = 0.95000, benign_loss = 0.28506
# benign_acc = 0.97000, benign_loss = 0.14476

# %% [markdown]
# ## FGSM

# %%
adv_examples, fgsm_acc, fgsm_loss = gen_adv_examples(model, adv_loader, fgsm, loss_fn)
print(f'fgsm_acc = {fgsm_acc:.5f}, fgsm_loss = {fgsm_loss:.5f}')

create_dir(root, 'fgsm', adv_examples, adv_names)

# %% [markdown]
# ## I-FGSM

# %%
# TODO: iterative fgsm attack
adv_examples0, ifgsm_acc0, ifgsm_loss0 = gen_adv_examples(models[0], adv_loader, ifgsm, loss_fn)
print(f'ID 0 : ifgsm_acc = {sum(ifgsm_acc0) / len(adv_loader.dataset):.5f}, ifgsm_loss = {ifgsm_loss0:.5f}')
adv_examples1, ifgsm_acc1, ifgsm_loss1 = gen_adv_examples(models[1], adv_loader, ifgsm, loss_fn)
print(f'ID 1 : ifgsm_acc = {sum(ifgsm_acc1) / len(adv_loader.dataset):.5f}, ifgsm_loss = {ifgsm_loss1:.5f}')
adv_examples2, ifgsm_acc2, ifgsm_loss2 = gen_adv_examples(models[2], adv_loader, ifgsm, loss_fn)
print(f'ID 2 : ifgsm_acc = {sum(ifgsm_acc2) / len(adv_loader.dataset):.5f}, ifgsm_loss = {ifgsm_loss2:.5f}')
adv_examples3, ifgsm_acc3, ifgsm_loss3 = gen_adv_examples(models[3], adv_loader, ifgsm, loss_fn)
print(f'ID 3 : ifgsm_acc = {sum(ifgsm_acc3) / len(adv_loader.dataset):.5f}, ifgsm_loss = {ifgsm_loss3:.5f}')
adv_examples4, ifgsm_acc4, ifgsm_loss4 = gen_adv_examples(models[4], adv_loader, ifgsm, loss_fn)
print(f'ID 4 : ifgsm_acc = {sum(ifgsm_acc4) / len(adv_loader.dataset):.5f}, ifgsm_loss = {ifgsm_loss4:.5f}')
# Out:
# ID 0 : ifgsm_acc = 0.09000, ifgsm_loss = 6.47213
# ID 1 : ifgsm_acc = 0.10000, ifgsm_loss = 4.02960
# ID 2 : ifgsm_acc = 0.05500, ifgsm_loss = 3.58150
# ID 3 : ifgsm_acc = 0.05500, ifgsm_loss = 6.06279
# ID 4 : ifgsm_acc = 0.10000, ifgsm_loss = 5.78751

# %%
adv_examples_list = [adv_examples0, adv_examples1, adv_examples2, adv_examples3, adv_examples4]
adv_examples = []

for i in range(len(adv_examples0) // batch_size):
    temp = [ifgsm_acc0[i], ifgsm_acc1[i], ifgsm_acc2[i], ifgsm_acc3[i], ifgsm_acc4[i]]
    min_acc_index = temp.index(min(temp))
    for j in range(i * batch_size, (i + 1) * batch_size):
        adv_examples.append(adv_examples_list[min_acc_index][j])

create_dir(root, 'ifgsm', adv_examples, adv_names)

# %% [markdown]
# ## Compress the images

# %%
# %cd fgsm
# !tar zcvf ../fgsm.tgz *
# %cd ..

# %cd ifgsm
# !tar zcvf ../ifgsm.tgz *
# %cd ..
# Out:
# Streaming output truncated to the last 5000 lines.
# datalab/web/node_modules/parseuri/test.js
# datalab/web/node_modules/parseuri/package.json
# datalab/web/node_modules/nan/
# datalab/web/node_modules/nan/nan_maybe_pre_43_inl.h
# datalab/web/node_modules/nan/tools/
# datalab/web/node_modules/nan/tools/README.md
# datalab/web/node_modules/nan/tools/1to2.js
# datalab/web/node_modules/nan/tools/package.json
# datalab/web/node_modules/nan/doc/
# datalab/web/node_modules/nan/doc/v8_internals.md
# datalab/web/node_modules/nan/doc/methods.md
# datalab/web/node_modules/nan/doc/string_bytes.md
# datalab/web/node_modules/nan/doc/new.md
# datalab/web/node_modules/nan/doc/node_misc.md
# datalab/web/node_modules/nan/doc/asyncworker.md
# datalab/web/node_modules/nan/doc/maybe_types.md
# datalab/web/node_modules/nan/doc/script.md
# datalab/web/node_modules/nan/doc/errors.md
# datalab/web/node_modules/nan/doc/callback.md
# datalab/web/node_modules/nan/doc/converters.md
# datalab/web/node_modules/nan/doc/persistent.md
# datalab/web/node_modules/nan/doc/v8_misc.md
# datalab/web/node_modules/nan/doc/json.md
# datalab/web/node_modules/nan/doc/buffers.md
# datalab/web/node_modules/nan/doc/object_wrappers.md
# datalab/web/node_modules/nan/doc/scopes.md
# datalab/web/node_modules/nan/nan_implementation_12_inl.h
# datalab/web/node_modules/nan/nan_converters.h
# datalab/web/node_modules/nan/nan_json.h
# datalab/web/node_modules/nan/README.md
# datalab/web/node_modules/nan/nan.h
# datalab/web/node_modules/nan/LICENSE.md
# datalab/web/node_modules/nan/CHANGELOG.md
# datalab/web/node_modules/nan/nan_callbacks.h
# datalab/web/node_modules/nan/nan_callbacks_12_inl.h
# datalab/web/node_modules/nan/nan_weak.h
# datalab/web/node_modules/nan/nan_private.h
# datalab/web/node_modules/nan/nan_persistent_pre_12_inl.h
# datalab/web/node_modules/nan/nan_string_bytes.h
# datalab/web/node_modules/nan/nan_object_wrap.h
# datalab/web/node_modules/nan/package.json
# datalab/web/node_modules/nan/nan_persistent_12_inl.h
# datalab/web/node_modules/nan/nan_define_own_property_helper.h
# datalab/web/node_modules/nan/nan_maybe_43_inl.h
# datalab/web/node_modules/nan/nan_new.h
# datalab/web/node_modules/nan/nan_converters_pre_43_inl.h
# datalab/web/node_modules/nan/nan_callbacks_pre_12_inl.h
# datalab/web/node_modules/nan/nan_typedarray_contents.h
# datalab/web/node_modules/nan/nan_converters_43_inl.h
# datalab/web/node_modules/nan/include_dirs.js
# datalab/web/node_modules/nan/nan_implementation_pre_12_inl.h
# datalab/web/node_modules/minimist/
# datalab/web/node_modules/minimist/test/
# datalab/web/node_modules/minimist/test/default_bool.js
# datalab/web/node_modules/minimist/test/short.js
# datalab/web/node_modules/minimist/test/long.js
# datalab/web/node_modules/moment/src/lib/units/week-year.js
# datalab/web/node_modules/moment/src/lib/units/priorities.js
# datalab/web/node_modules/moment/src/lib/units/hour.js
# datalab/web/node_modules/moment/src/lib/units/week-calendar-utils.js
# datalab/web/node_modules/moment/src/lib/units/millisecond.js
# datalab/web/node_modules/moment/src/lib/units/quarter.js
# datalab/web/node_modules/moment/src/lib/units/timestamp.js
# datalab/web/node_modules/moment/src/lib/units/year.js
# datalab/web/node_modules/moment/src/lib/units/week.js
# datalab/web/node_modules/moment/src/lib/units/minute.js
# datalab/web/node_modules/moment/src/lib/units/aliases.js
# datalab/web/node_modules/moment/src/lib/units/offset.js
# datalab/web/node_modules/moment/src/lib/units/day-of-year.js
# datalab/web/node_modules/moment/src/lib/moment/
# datalab/web/node_modules/moment/src/lib/moment/creation-data.js
# datalab/web/node_modules/moment/src/lib/moment/from.js
# datalab/web/node_modules/moment/src/lib/moment/moment.js
# datalab/web/node_modules/moment/src/lib/moment/to-type.js
# datalab/web/node_modules/moment/src/lib/moment/to.js
# datalab/web/node_modules/moment/src/lib/moment/prototype.js
# datalab/web/node_modules/moment/src/lib/moment/now.js
# datalab/web/node_modules/moment/src/lib/moment/add-subtract.js
# datalab/web/node_modules/moment/src/lib/moment/calendar.js
# datalab/web/node_modules/moment/src/lib/moment/compare.js
# datalab/web/node_modules/moment/src/lib/moment/get-set.js
# datalab/web/node_modules/moment/src/lib/moment/start-end-of.js
# datalab/web/node_modules/moment/src/lib/moment/format.js
# datalab/web/node_modules/moment/src/lib/moment/clone.js
# datalab/web/node_modules/moment/src/lib/moment/min-max.js
# datalab/web/node_modules/moment/src/lib/moment/valid.js
# datalab/web/node_modules/moment/src/lib/moment/diff.js
# datalab/web/node_modules/moment/src/lib/moment/locale.js
# datalab/web/node_modules/moment/src/lib/moment/constructor.js
# datalab/web/node_modules/moment/src/lib/create/
# datalab/web/node_modules/moment/src/lib/create/from-string.js
# datalab/web/node_modules/moment/src/lib/create/from-object.js
# datalab/web/node_modules/moment/src/lib/create/from-anything.js
# datalab/web/node_modules/moment/src/lib/create/check-overflow.js
# datalab/web/node_modules/moment/src/lib/create/from-array.js
# datalab/web/node_modules/moment/src/lib/create/from-string-and-array.js
# datalab/web/node_modules/moment/src/lib/create/from-string-and-format.js
# datalab/web/node_modules/moment/src/lib/create/utc.js
# datalab/web/node_modules/moment/src/lib/create/valid.js
# datalab/web/node_modules/moment/src/lib/create/date-from-array.js
# datalab/web/node_modules/moment/src/lib/create/parsing-flags.js
# datalab/web/node_modules/moment/src/lib/create/local.js
# datalab/web/node_modules/moment/src/lib/utils/
# datalab/web/node_modules/moment/src/lib/utils/hooks.js
# datalab/web/node_modules/moment/src/lib/utils/is-number.js
# datalab/web/node_modules/moment/src/lib/utils/is-undefined.js
# datalab/web/node_modules/moment/src/lib/utils/abs-round.js
# datalab/web/node_modules/moment/src/lib/utils/abs-floor.js
# datalab/web/node_modules/moment/src/lib/utils/compare-arrays.js
# datalab/web/node_modules/moment/src/lib/utils/is-function.js
# datalab/web/node_modules/moment/src/lib/utils/is-array.js
# datalab/web/node_modules/moment/src/lib/utils/defaults.js
# datalab/web/node_modules/moment/src/lib/utils/to-int.js
# datalab/web/node_modules/moment/src/lib/utils/is-date.js
# datalab/web/node_modules/moment/src/lib/utils/is-object-empty.js
# datalab/web/node_modules/moment/src/lib/utils/extend.js
# datalab/web/node_modules/moment/src/lib/utils/has-own-prop.js
# datalab/web/node_modules/moment/src/lib/utils/is-object.js
# datalab/web/node_modules/moment/src/lib/utils/mod.js
# datalab/web/node_modules/moment/src/lib/utils/index-of.js
# datalab/web/node_modules/moment/src/lib/utils/keys.js
# datalab/web/node_modules/moment/src/lib/utils/zero-fill.js
# datalab/web/node_modules/moment/src/lib/utils/abs-ceil.js
# datalab/web/node_modules/moment/src/lib/utils/some.js
# datalab/web/node_modules/moment/src/lib/utils/map.js
# datalab/web/node_modules/moment/src/lib/utils/deprecate.js
# datalab/web/node_modules/moment/src/lib/format/
# datalab/web/node_modules/moment/src/lib/format/format.js
# datalab/web/node_modules/moment/min/
# datalab/web/node_modules/moment/min/locales.js
# datalab/web/node_modules/moment/min/moment.min.js
# datalab/web/node_modules/moment/min/moment-with-locales.js
# datalab/web/node_modules/moment/min/locales.min.js
# datalab/web/node_modules/moment/min/moment-with-locales.min.js
# datalab/web/node_modules/moment/LICENSE
# datalab/web/node_modules/moment/package.js
# datalab/web/node_modules/moment/package.json
# datalab/web/node_modules/better-assert/
# datalab/web/node_modules/better-assert/index.js
# datalab/web/node_modules/better-assert/.npmignore
# datalab/web/node_modules/better-assert/History.md
# datalab/web/node_modules/better-assert/Makefile
# datalab/web/node_modules/better-assert/Readme.md
# datalab/web/node_modules/better-assert/example.js
# datalab/web/node_modules/better-assert/package.json
# datalab/web/node_modules/object-component/
# datalab/web/node_modules/object-component/test/
# datalab/web/node_modules/object-component/test/object.js
# datalab/web/node_modules/object-component/component.json
# datalab/web/node_modules/object-component/index.js
# datalab/web/node_modules/object-component/.npmignore
# datalab/web/node_modules/object-component/History.md
# datalab/web/node_modules/object-component/Makefile
# datalab/web/node_modules/object-component/Readme.md
# datalab/web/node_modules/object-component/package.json
# datalab/web/node_modules/ultron/
# datalab/web/node_modules/ultron/README.md
# datalab/web/node_modules/ultron/index.js
# datalab/web/node_modules/ultron/LICENSE
# datalab/web/node_modules/ultron/package.json
# datalab/web/node_modules/component-emitter/
# datalab/web/node_modules/component-emitter/index.js
# datalab/web/node_modules/component-emitter/History.md
# datalab/web/node_modules/component-emitter/Readme.md
# datalab/web/node_modules/component-emitter/LICENSE
# datalab/web/node_modules/component-emitter/package.json
# datalab/web/node_modules/options/
# datalab/web/node_modules/options/lib/
# datalab/web/node_modules/options/lib/options.js
# datalab/web/node_modules/options/README.md
# datalab/web/node_modules/options/.npmignore
# datalab/web/node_modules/options/Makefile
# datalab/web/node_modules/options/package.json
# datalab/web/node_modules/socket.io-adapter/
# datalab/web/node_modules/socket.io-adapter/index.js
# datalab/web/node_modules/socket.io-adapter/.npmignore
# datalab/web/node_modules/socket.io-adapter/Readme.md
# datalab/web/node_modules/socket.io-adapter/LICENSE
# datalab/web/node_modules/socket.io-adapter/package.json
# datalab/web/node_modules/safe-json-stringify/
# datalab/web/node_modules/safe-json-stringify/README.md
# datalab/web/node_modules/safe-json-stringify/index.js
# datalab/web/node_modules/safe-json-stringify/.travis.yml
# datalab/web/node_modules/safe-json-stringify/.idea/
# datalab/web/node_modules/safe-json-stringify/.idea/modules.xml
# datalab/web/node_modules/safe-json-stringify/.idea/misc.xml
# datalab/web/node_modules/safe-json-stringify/.idea/vcs.xml
# datalab/web/node_modules/safe-json-stringify/.idea/workspace.xml
# datalab/web/node_modules/safe-json-stringify/.idea/safe-json-stringify.iml
# datalab/web/node_modules/safe-json-stringify/package.json
# datalab/web/node_modules/accepts/
# datalab/web/node_modules/accepts/HISTORY.md
# datalab/web/node_modules/accepts/README.md
# datalab/web/node_modules/accepts/index.js
# datalab/web/node_modules/accepts/LICENSE
# datalab/web/node_modules/accepts/package.json
# datalab/web/node_modules/eventemitter3/
# datalab/web/node_modules/eventemitter3/README.md
# datalab/web/node_modules/eventemitter3/index.js
# datalab/web/node_modules/eventemitter3/LICENSE
# datalab/web/node_modules/eventemitter3/package.json
# datalab/web/node_modules/eventemitter3/index.d.ts
# datalab/web/node_modules/eventemitter3/umd/
# datalab/web/node_modules/eventemitter3/umd/eventemitter3.min.js
# datalab/web/node_modules/eventemitter3/umd/eventemitter3.min.js.map
# datalab/web/node_modules/eventemitter3/umd/eventemitter3.js
# datalab/web/node_modules/dtrace-provider/
# datalab/web/node_modules/dtrace-provider/libusdt/
# datalab/web/node_modules/dtrace-provider/libusdt/usdt_tracepoints_x86_64.s
# datalab/web/node_modules/dtrace-provider/libusdt/usdt_dof.c
# datalab/web/node_modules/dtrace-provider/libusdt/README.md
# datalab/web/node_modules/dtrace-provider/libusdt/test_usdt.c
# datalab/web/node_modules/dtrace-provider/libusdt/usdt.c
# datalab/web/node_modules/dtrace-provider/libusdt/usdt_dof_file.c
# datalab/web/node_modules/dtrace-provider/libusdt/.npmignore
# datalab/web/node_modules/dtrace-provider/libusdt/usdt.h
# datalab/web/node_modules/dtrace-provider/libusdt/usdt_internal.h
# datalab/web/node_modules/dtrace-provider/libusdt/test_mem_usage.c
# datalab/web/node_modules/dtrace-provider/libusdt/Makefile
# datalab/web/node_modules/dtrace-provider/libusdt/usdt_dof_sections.c
# datalab/web/node_modules/dtrace-provider/libusdt/LICENCE
# datalab/web/node_modules/dtrace-provider/libusdt/test.pl
# datalab/web/node_modules/dtrace-provider/libusdt/usdt_probe.c
# datalab/web/node_modules/dtrace-provider/libusdt/usdt_tracepoints_i386.s
# datalab/web/node_modules/dtrace-provider/.gitmodules
# datalab/web/node_modules/dtrace-provider/README.md
# datalab/web/node_modules/dtrace-provider/build.sh
# datalab/web/node_modules/dtrace-provider/CHANGES.md
# datalab/web/node_modules/dtrace-provider/.npmignore
# datalab/web/node_modules/dtrace-provider/src/
# datalab/web/node_modules/dtrace-provider/src/dtrace_provider.cc
# datalab/web/node_modules/dtrace-provider/src/dtrace_provider.h
# datalab/web/node_modules/dtrace-provider/src/dtrace_probe.cc
# datalab/web/node_modules/dtrace-provider/src/dtrace_argument.cc
# datalab/web/node_modules/dtrace-provider/src/binding.gyp
# datalab/web/node_modules/dtrace-provider/LICENCE
# datalab/web/node_modules/dtrace-provider/suppress-error.js
# datalab/web/node_modules/dtrace-provider/package.json
# datalab/web/node_modules/dtrace-provider/dtrace-provider.js
# datalab/web/node_modules/dtrace-provider/binding.gyp
# datalab/web/node_modules/dtrace-provider/build/
# datalab/web/node_modules/dtrace-provider/build/Makefile
# datalab/web/node_modules/dtrace-provider/build/binding.Makefile
# datalab/web/node_modules/dtrace-provider/build/Release/
# datalab/web/node_modules/dtrace-provider/build/Release/.deps/
# datalab/web/node_modules/dtrace-provider/build/Release/.deps/Release/
# datalab/web/node_modules/dtrace-provider/build/Release/.deps/Release/obj.target/
# datalab/web/node_modules/dtrace-provider/build/Release/.deps/Release/obj.target/DTraceProviderStub.stamp.d
# datalab/web/node_modules/dtrace-provider/build/Release/obj.target/
# datalab/web/node_modules/dtrace-provider/build/Release/obj.target/DTraceProviderStub.stamp
# datalab/web/node_modules/dtrace-provider/build/DTraceProviderStub.target.mk
# datalab/web/node_modules/dtrace-provider/build/config.gypi
# datalab/web/node_modules/socket.io/
# datalab/web/node_modules/socket.io/lib/
# datalab/web/node_modules/socket.io/lib/parent-namespace.js
# datalab/web/node_modules/socket.io/lib/namespace.js
# datalab/web/node_modules/socket.io/lib/index.js
# datalab/web/node_modules/socket.io/lib/socket.js
# datalab/web/node_modules/socket.io/lib/client.js
# datalab/web/node_modules/socket.io/Readme.md
# datalab/web/node_modules/socket.io/LICENSE
# datalab/web/node_modules/socket.io/package.json
# datalab/web/node_modules/.bin/
# datalab/web/node_modules/.bin/mkdirp
# datalab/web/node_modules/.bin/semver
# datalab/web/node_modules/.bin/ncp
# datalab/web/node_modules/.bin/bunyan
# datalab/web/node_modules/.bin/rimraf
# datalab/web/node_modules/mv/
# datalab/web/node_modules/mv/README.md
# datalab/web/node_modules/mv/test/
# datalab/web/node_modules/mv/test/a-file
# datalab/web/node_modules/mv/test/test.js
# datalab/web/node_modules/mv/test/a-folder/
# datalab/web/node_modules/mv/test/a-folder/another-file
# datalab/web/node_modules/mv/test/a-folder/another-folder/
# datalab/web/node_modules/mv/test/a-folder/another-folder/file3
# datalab/web/node_modules/mv/index.js
# datalab/web/node_modules/mv/.npmignore
# datalab/web/node_modules/mv/.travis.yml
# datalab/web/node_modules/mv/LICENSE
# datalab/web/node_modules/mv/package.json
# datalab/web/node_modules/socket.io-parser/
# datalab/web/node_modules/socket.io-parser/index.js
# datalab/web/node_modules/socket.io-parser/Readme.md
# datalab/web/node_modules/socket.io-parser/LICENSE
# datalab/web/node_modules/socket.io-parser/binary.js
# datalab/web/node_modules/socket.io-parser/is-buffer.js
# datalab/web/node_modules/socket.io-parser/package.json
# datalab/web/node_modules/minimatch/
# datalab/web/node_modules/minimatch/README.md
# datalab/web/node_modules/minimatch/minimatch.js
# datalab/web/node_modules/minimatch/LICENSE
# datalab/web/node_modules/minimatch/package.json
# datalab/web/node_modules/inflight/
# datalab/web/node_modules/inflight/README.md
# datalab/web/node_modules/inflight/inflight.js
# datalab/web/node_modules/inflight/LICENSE
# datalab/web/node_modules/inflight/package.json
# datalab/web/node_modules/to-array/
# datalab/web/node_modules/to-array/README.md
# datalab/web/node_modules/to-array/index.js
# datalab/web/node_modules/to-array/.npmignore
# datalab/web/node_modules/to-array/LICENCE
# datalab/web/node_modules/to-array/package.json
# datalab/web/node_modules/arraybuffer.slice/
# datalab/web/node_modules/arraybuffer.slice/README.md
# datalab/web/node_modules/arraybuffer.slice/test/
# datalab/web/node_modules/arraybuffer.slice/test/slice-buffer.js
# datalab/web/node_modules/arraybuffer.slice/index.js
# datalab/web/node_modules/arraybuffer.slice/.npmignore
# datalab/web/node_modules/arraybuffer.slice/Makefile
# datalab/web/node_modules/arraybuffer.slice/LICENCE
# datalab/web/node_modules/arraybuffer.slice/package.json
# datalab/web/node_modules/callsite/
# datalab/web/node_modules/callsite/index.js
# datalab/web/node_modules/callsite/.npmignore
# datalab/web/node_modules/callsite/History.md
# datalab/web/node_modules/callsite/Makefile
# datalab/web/node_modules/callsite/Readme.md
# datalab/web/node_modules/callsite/package.json
# datalab/web/node_modules/backo2/
# datalab/web/node_modules/backo2/test/
# datalab/web/node_modules/backo2/test/index.js
# datalab/web/node_modules/backo2/component.json
# datalab/web/node_modules/backo2/index.js
# datalab/web/node_modules/backo2/.npmignore
# datalab/web/node_modules/backo2/History.md
# datalab/web/node_modules/backo2/Makefile
# datalab/web/node_modules/backo2/Readme.md
# datalab/web/node_modules/backo2/package.json
# datalab/web/node_modules/node-pty/
# datalab/web/node_modules/node-pty/lib/
# datalab/web/node_modules/node-pty/lib/windowsTerminal.test.js
# datalab/web/node_modules/node-pty/lib/unixTerminal.test.js
# datalab/web/node_modules/node-pty/lib/terminal.test.js.map
# datalab/web/node_modules/node-pty/lib/testUtils.test.js.map
# datalab/web/node_modules/node-pty/lib/types.js.map
# datalab/web/node_modules/node-pty/lib/conpty_console_list_agent.js
# datalab/web/node_modules/node-pty/lib/eventEmitter2.js.map
# datalab/web/node_modules/node-pty/lib/unixTerminal.js
# datalab/web/node_modules/node-pty/lib/windowsTerminal.js.map
# datalab/web/node_modules/node-pty/lib/terminal.test.js
# datalab/web/node_modules/node-pty/lib/index.js
# datalab/web/node_modules/node-pty/lib/windowsTerminal.js
# datalab/web/node_modules/node-pty/lib/terminal.js
# datalab/web/node_modules/node-pty/lib/index.js.map
# datalab/web/node_modules/node-pty/lib/eventEmitter2.test.js.map
# datalab/web/node_modules/node-pty/lib/interfaces.js
# datalab/web/node_modules/node-pty/lib/windowsPtyAgent.test.js
# datalab/web/node_modules/node-pty/lib/windowsPtyAgent.js
# datalab/web/node_modules/node-pty/lib/types.js
# datalab/web/node_modules/node-pty/lib/windowsPtyAgent.js.map
# datalab/web/node_modules/node-pty/lib/utils.js
# datalab/web/node_modules/node-pty/lib/eventEmitter2.js
# datalab/web/node_modules/node-pty/lib/interfaces.js.map
# datalab/web/node_modules/node-pty/lib/unixTerminal.test.js.map
# datalab/web/node_modules/node-pty/lib/unixTerminal.js.map
# datalab/web/node_modules/node-pty/lib/conpty_console_list_agent.js.map
# datalab/web/node_modules/node-pty/lib/windowsTerminal.test.js.map
# datalab/web/node_modules/node-pty/lib/utils.js.map
# datalab/web/node_modules/node-pty/lib/windowsPtyAgent.test.js.map
# datalab/web/node_modules/node-pty/lib/eventEmitter2.test.js
# datalab/web/node_modules/node-pty/lib/testUtils.test.js
# datalab/web/node_modules/node-pty/lib/terminal.js.map
# datalab/web/node_modules/node-pty/README.md
# datalab/web/node_modules/node-pty/src/
# datalab/web/node_modules/node-pty/src/terminal.ts
# datalab/web/node_modules/node-pty/src/windowsTerminal.test.ts
# datalab/web/node_modules/node-pty/src/windowsPtyAgent.ts
# datalab/web/node_modules/node-pty/src/terminal.test.ts
# datalab/web/node_modules/node-pty/src/windowsPtyAgent.test.ts
# datalab/web/node_modules/node-pty/src/interfaces.ts
# datalab/web/node_modules/node-pty/src/eventEmitter2.ts
# datalab/web/node_modules/node-pty/src/native.d.ts
# datalab/web/node_modules/node-pty/src/unixTerminal.test.ts
# datalab/web/node_modules/node-pty/src/unixTerminal.ts
# datalab/web/node_modules/node-pty/src/eventEmitter2.test.ts
# datalab/web/node_modules/node-pty/src/windowsTerminal.ts
# datalab/web/node_modules/node-pty/src/testUtils.test.ts
# datalab/web/node_modules/node-pty/src/unix/
# datalab/web/node_modules/node-pty/src/unix/pty.cc
# datalab/web/node_modules/node-pty/src/win/
# datalab/web/node_modules/node-pty/src/win/path_util.h
# datalab/web/node_modules/node-pty/src/win/conpty.cc
# datalab/web/node_modules/node-pty/src/win/winpty.cc
# datalab/web/node_modules/node-pty/src/win/conpty_console_list.cc
# datalab/web/node_modules/node-pty/src/win/path_util.cc
# datalab/web/node_modules/node-pty/src/utils.ts
# datalab/web/node_modules/node-pty/src/types.ts
# datalab/web/node_modules/node-pty/src/index.ts
# datalab/web/node_modules/node-pty/src/conpty_console_list_agent.ts
# datalab/web/node_modules/node-pty/deps/
# datalab/web/node_modules/node-pty/deps/.editorconfig
# datalab/web/node_modules/node-pty/deps/winpty/
# datalab/web/node_modules/node-pty/deps/winpty/.gitattributes
# datalab/web/node_modules/node-pty/deps/winpty/README.md
# datalab/web/node_modules/node-pty/deps/winpty/.drone.yml
# datalab/web/node_modules/node-pty/deps/winpty/ship/
# datalab/web/node_modules/node-pty/deps/winpty/ship/make_msvc_package.py
# datalab/web/node_modules/node-pty/deps/winpty/ship/common_ship.py
# datalab/web/node_modules/node-pty/deps/winpty/ship/ship.py
# datalab/web/node_modules/node-pty/deps/winpty/ship/build-pty4j-libpty.bat
# datalab/web/node_modules/node-pty/deps/winpty/.npmignore
# datalab/web/node_modules/node-pty/deps/winpty/Makefile
# datalab/web/node_modules/node-pty/deps/winpty/src/
# datalab/web/node_modules/node-pty/deps/winpty/src/debugserver/
# datalab/web/node_modules/node-pty/deps/winpty/src/debugserver/DebugServer.cc
# datalab/web/node_modules/node-pty/deps/winpty/src/debugserver/subdir.mk
# datalab/web/node_modules/node-pty/deps/winpty/src/unix-adapter/
# datalab/web/node_modules/node-pty/deps/winpty/src/unix-adapter/WakeupFd.cc
# datalab/web/node_modules/node-pty/deps/winpty/src/unix-adapter/OutputHandler.cc
# datalab/web/node_modules/node-pty/deps/winpty/src/unix-adapter/InputHandler.h
# datalab/web/node_modules/node-pty/deps/winpty/src/unix-adapter/InputHandler.cc
# datalab/web/node_modules/node-pty/deps/winpty/src/unix-adapter/WakeupFd.h
# datalab/web/node_modules/node-pty/deps/winpty/src/unix-adapter/OutputHandler.h
# datalab/web/node_modules/node-pty/deps/winpty/src/unix-adapter/subdir.mk
# datalab/web/node_modules/node-pty/deps/winpty/src/unix-adapter/Util.h
# datalab/web/node_modules/node-pty/deps/winpty/src/unix-adapter/Util.cc
# datalab/web/node_modules/node-pty/deps/winpty/src/unix-adapter/main.cc
# datalab/web/node_modules/node-pty/deps/winpty/src/libwinpty/
# datalab/web/node_modules/node-pty/deps/winpty/src/libwinpty/AgentLocation.cc
# datalab/web/node_modules/node-pty/deps/winpty/src/libwinpty/winpty.cc
# datalab/web/node_modules/node-pty/deps/winpty/src/libwinpty/subdir.mk
# datalab/web/node_modules/node-pty/deps/winpty/src/libwinpty/WinptyInternal.h
# datalab/web/node_modules/node-pty/deps/winpty/src/libwinpty/AgentLocation.h
# datalab/web/node_modules/node-pty/deps/winpty/src/libwinpty/LibWinptyException.h
# datalab/web/node_modules/node-pty/deps/winpty/src/tests/
# datalab/web/node_modules/node-pty/deps/winpty/src/tests/subdir.mk
# datalab/web/node_modules/node-pty/deps/winpty/src/tests/trivial_test.cc
# datalab/web/node_modules/node-pty/deps/winpty/src/configurations.gypi
# datalab/web/node_modules/node-pty/deps/winpty/src/winpty.gyp
# datalab/web/node_modules/node-pty/deps/winpty/src/subdir.mk
# datalab/web/node_modules/node-pty/deps/winpty/src/shared/
# datalab/web/node_modules/node-pty/deps/winpty/src/shared/BackgroundDesktop.cc
# datalab/web/node_modules/node-pty/deps/winpty/src/shared/StringUtil.cc
# datalab/web/node_modules/node-pty/deps/winpty/src/shared/WinptyAssert.h
# datalab/web/node_modules/node-pty/deps/winpty/src/shared/StringUtil.h
# datalab/web/node_modules/node-pty/deps/winpty/src/shared/UnixCtrlChars.h
# datalab/web/node_modules/node-pty/deps/winpty/src/shared/GenRandom.h
# datalab/web/node_modules/node-pty/deps/winpty/src/shared/WindowsSecurity.cc
# datalab/web/node_modules/node-pty/deps/winpty/src/shared/winpty_snprintf.h
# datalab/web/node_modules/node-pty/deps/winpty/src/shared/OsModule.h
# datalab/web/node_modules/node-pty/deps/winpty/src/shared/PrecompiledHeader.h
# datalab/web/node_modules/node-pty/deps/winpty/src/shared/TimeMeasurement.h
# datalab/web/node_modules/node-pty/deps/winpty/src/shared/WinptyException.h
# datalab/web/node_modules/node-pty/deps/winpty/src/shared/StringBuilder.h
# datalab/web/node_modules/node-pty/deps/winpty/src/shared/UpdateGenVersion.bat
# datalab/web/node_modules/node-pty/deps/winpty/src/shared/WinptyException.cc
# datalab/web/node_modules/node-pty/deps/winpty/src/shared/WindowsVersion.cc
# datalab/web/node_modules/node-pty/deps/winpty/src/shared/Buffer.cc
# datalab/web/node_modules/node-pty/deps/winpty/src/shared/GenRandom.cc
# datalab/web/node_modules/node-pty/deps/winpty/src/shared/GetCommitHash.bat
# datalab/web/node_modules/node-pty/deps/winpty/src/shared/BackgroundDesktop.h
# datalab/web/node_modules/node-pty/deps/winpty/src/shared/Mutex.h
# datalab/web/node_modules/node-pty/deps/winpty/src/shared/WindowsSecurity.h
# datalab/web/node_modules/node-pty/deps/winpty/src/shared/WindowsVersion.h
# datalab/web/node_modules/node-pty/deps/winpty/src/shared/DebugClient.h
# datalab/web/node_modules/node-pty/deps/winpty/src/shared/WinptyAssert.cc
# datalab/web/node_modules/node-pty/deps/winpty/src/shared/Buffer.h
# datalab/web/node_modules/node-pty/deps/winpty/src/shared/AgentMsg.h
# datalab/web/node_modules/node-pty/deps/winpty/src/shared/OwnedHandle.h
# datalab/web/node_modules/node-pty/deps/winpty/src/shared/OwnedHandle.cc
# datalab/web/node_modules/node-pty/deps/winpty/src/shared/WinptyVersion.cc
# datalab/web/node_modules/node-pty/deps/winpty/src/shared/DebugClient.cc
# datalab/web/node_modules/node-pty/deps/winpty/src/shared/StringBuilderTest.cc
# datalab/web/node_modules/node-pty/deps/winpty/src/shared/WinptyVersion.h
# datalab/web/node_modules/node-pty/deps/winpty/src/agent/
# datalab/web/node_modules/node-pty/deps/winpty/src/agent/Scraper.h
# datalab/web/node_modules/node-pty/deps/winpty/src/agent/InputMap.h
# datalab/web/node_modules/node-pty/deps/winpty/src/agent/AgentCreateDesktop.h
# datalab/web/node_modules/node-pty/deps/winpty/src/agent/Coord.h
# datalab/web/node_modules/node-pty/deps/winpty/src/agent/LargeConsoleRead.h
# datalab/web/node_modules/node-pty/deps/winpty/src/agent/DebugShowInput.cc
# datalab/web/node_modules/node-pty/deps/winpty/src/agent/Win32ConsoleBuffer.h
# datalab/web/node_modules/node-pty/deps/winpty/src/agent/Win32ConsoleBuffer.cc
# datalab/web/node_modules/node-pty/deps/winpty/src/agent/EventLoop.h
# datalab/web/node_modules/node-pty/deps/winpty/src/agent/SimplePool.h
# datalab/web/node_modules/node-pty/deps/winpty/src/agent/ConsoleLine.cc
# datalab/web/node_modules/node-pty/deps/winpty/src/agent/UnicodeEncoding.h
# datalab/web/node_modules/node-pty/deps/winpty/src/agent/Terminal.cc
# datalab/web/node_modules/node-pty/deps/winpty/src/agent/Agent.h
# datalab/web/node_modules/node-pty/deps/winpty/src/agent/AgentCreateDesktop.cc
# datalab/web/node_modules/node-pty/deps/winpty/src/agent/DsrSender.h
# datalab/web/node_modules/node-pty/deps/winpty/src/agent/LargeConsoleRead.cc
# datalab/web/node_modules/node-pty/deps/winpty/src/agent/EventLoop.cc
# datalab/web/node_modules/node-pty/deps/winpty/src/agent/Scraper.cc
# datalab/web/node_modules/node-pty/deps/winpty/src/agent/NamedPipe.cc
# datalab/web/node_modules/node-pty/deps/winpty/src/agent/ConsoleInput.cc
# datalab/web/node_modules/node-pty/deps/winpty/src/agent/Terminal.h
# datalab/web/node_modules/node-pty/deps/winpty/src/agent/DefaultInputMap.cc
# datalab/web/node_modules/node-pty/deps/winpty/src/agent/SmallRect.h
# datalab/web/node_modules/node-pty/deps/winpty/src/agent/Agent.cc
# datalab/web/node_modules/node-pty/deps/winpty/src/agent/ConsoleFont.cc
# datalab/web/node_modules/node-pty/deps/winpty/src/agent/ConsoleLine.h
# datalab/web/node_modules/node-pty/deps/winpty/src/agent/ConsoleInputReencoding.h
# datalab/web/node_modules/node-pty/deps/winpty/src/agent/NamedPipe.h
# datalab/web/node_modules/node-pty/deps/winpty/src/agent/UnicodeEncodingTest.cc
# datalab/web/node_modules/node-pty/deps/winpty/src/agent/subdir.mk
# datalab/web/node_modules/node-pty/deps/winpty/src/agent/ConsoleInputReencoding.cc
# datalab/web/node_modules/node-pty/deps/winpty/src/agent/Win32Console.cc
# datalab/web/node_modules/node-pty/deps/winpty/src/agent/InputMap.cc
# datalab/web/node_modules/node-pty/deps/winpty/src/agent/DebugShowInput.h
# datalab/web/node_modules/node-pty/deps/winpty/src/agent/ConsoleInput.h
# datalab/web/node_modules/node-pty/deps/winpty/src/agent/Win32Console.h
# datalab/web/node_modules/node-pty/deps/winpty/src/agent/main.cc
# datalab/web/node_modules/node-pty/deps/winpty/src/agent/DefaultInputMap.h
# datalab/web/node_modules/node-pty/deps/winpty/src/agent/ConsoleFont.h
# datalab/web/node_modules/node-pty/deps/winpty/src/include/
# datalab/web/node_modules/node-pty/deps/winpty/src/include/winpty.h
# datalab/web/node_modules/node-pty/deps/winpty/src/include/winpty_constants.h
# datalab/web/node_modules/node-pty/deps/winpty/configure
# datalab/web/node_modules/node-pty/deps/winpty/LICENSE
# datalab/web/node_modules/node-pty/deps/winpty/RELEASES.md
# datalab/web/node_modules/node-pty/deps/winpty/vcbuild.bat
# datalab/web/node_modules/node-pty/deps/winpty/VERSION.txt
# datalab/web/node_modules/node-pty/deps/winpty/misc/
# datalab/web/node_modules/node-pty/deps/winpty/misc/BufferResizeTests.cc
# datalab/web/node_modules/node-pty/deps/winpty/misc/winbug-15048.cc
# datalab/web/node_modules/node-pty/deps/winpty/misc/UnixEcho.cc
# datalab/web/node_modules/node-pty/deps/winpty/misc/EnableExtendedFlags.txt
# datalab/web/node_modules/node-pty/deps/winpty/misc/Spew.py
# datalab/web/node_modules/node-pty/deps/winpty/misc/ShowArgv.cc
# datalab/web/node_modules/node-pty/deps/winpty/misc/DebugClient.py
# datalab/web/node_modules/node-pty/deps/winpty/misc/build64.sh
# datalab/web/node_modules/node-pty/deps/winpty/misc/Win10WrapTest1.cc
# datalab/web/node_modules/node-pty/deps/winpty/misc/ConinMode.cc
# datalab/web/node_modules/node-pty/deps/winpty/misc/FreezePerfTest.cc
# datalab/web/node_modules/node-pty/deps/winpty/misc/UnicodeWideTest1.cc
# datalab/web/node_modules/node-pty/deps/winpty/misc/VkEscapeTest.cc
# datalab/web/node_modules/node-pty/deps/winpty/misc/WindowsBugCrashReader.cc
# datalab/web/node_modules/node-pty/deps/winpty/misc/Notes.txt
# datalab/web/node_modules/node-pty/deps/winpty/misc/Font-Report-June2016/
# datalab/web/node_modules/node-pty/deps/winpty/misc/Font-Report-June2016/CP949.txt
# datalab/web/node_modules/node-pty/deps/winpty/misc/Font-Report-June2016/Windows10SetFontBugginess.txt
# datalab/web/node_modules/node-pty/deps/winpty/misc/Font-Report-June2016/CP950.txt
# datalab/web/node_modules/node-pty/deps/winpty/misc/Font-Report-June2016/CP932.txt
# datalab/web/node_modules/node-pty/deps/winpty/misc/Font-Report-June2016/CP936.txt
# datalab/web/node_modules/node-pty/deps/winpty/misc/Font-Report-June2016/MinimumWindowWidths.txt
# datalab/web/node_modules/node-pty/deps/winpty/misc/Font-Report-June2016/CP437-Lucida.txt
# datalab/web/node_modules/node-pty/deps/winpty/misc/Font-Report-June2016/CP437-Consolas.txt
# datalab/web/node_modules/node-pty/deps/winpty/misc/Font-Report-June2016/Results.txt
# datalab/web/node_modules/node-pty/deps/winpty/misc/ClearConsole.cc
# datalab/web/node_modules/node-pty/deps/winpty/misc/SetCursorPos.cc
# datalab/web/node_modules/node-pty/deps/winpty/misc/ConinMode.ps1
# datalab/web/node_modules/node-pty/deps/winpty/misc/Win32Echo2.cc
# datalab/web/node_modules/node-pty/deps/winpty/misc/MouseInputNotes.txt
# datalab/web/node_modules/node-pty/deps/winpty/misc/GetFont.cc
# datalab/web/node_modules/node-pty/deps/winpty/misc/DebugServer.py
# datalab/web/node_modules/node-pty/deps/winpty/misc/ShowConsoleInput.cc
# datalab/web/node_modules/node-pty/deps/winpty/misc/SetWindowRect.cc
# datalab/web/node_modules/node-pty/deps/winpty/misc/.npmignore
# datalab/web/node_modules/node-pty/deps/winpty/misc/SelectAllTest.cc
# datalab/web/node_modules/node-pty/deps/winpty/misc/SetFont.cc
# datalab/web/node_modules/node-pty/deps/winpty/misc/SetBufferSize.cc
# datalab/web/node_modules/node-pty/deps/winpty/misc/UnicodeDoubleWidthTest.cc
# datalab/web/node_modules/node-pty/deps/winpty/misc/GetConsolePos.cc
# datalab/web/node_modules/node-pty/deps/winpty/misc/ChangeScreenBuffer.cc
# datalab/web/node_modules/node-pty/deps/winpty/misc/FormatChar.h
# datalab/web/node_modules/node-pty/deps/winpty/misc/ScreenBufferTest.cc
# datalab/web/node_modules/node-pty/deps/winpty/misc/Win32Test1.cc
# datalab/web/node_modules/node-pty/deps/winpty/misc/IsNewConsole.cc
# datalab/web/node_modules/node-pty/deps/winpty/misc/MoveConsoleWindow.cc
# datalab/web/node_modules/node-pty/deps/winpty/misc/Win32Test3.cc
# datalab/web/node_modules/node-pty/deps/winpty/misc/Win10ResizeWhileFrozen.cc
# datalab/web/node_modules/node-pty/deps/winpty/misc/ConoutMode.cc
# datalab/web/node_modules/node-pty/deps/winpty/misc/TestUtil.cc
# datalab/web/node_modules/node-pty/deps/winpty/misc/font-notes.txt
# datalab/web/node_modules/node-pty/deps/winpty/misc/build32.sh
# datalab/web/node_modules/node-pty/deps/winpty/misc/ScreenBufferTest2.cc
# datalab/web/node_modules/node-pty/deps/winpty/misc/OSVersion.cc
# ...
# opt/nvidia/nsight-systems/2020.3.2/target-linux-x64/nvtx/include/nvtx3/nvtxDetail/nvtxInitDecls.h
# opt/nvidia/nsight-systems/2020.3.2/target-linux-x64/nvtx/include/nvtx3/nvtxDetail/nvtxTypes.h
# opt/nvidia/nsight-systems/2020.3.2/target-linux-x64/nvtx/include/nvtx3/nvtxDetail/nvtxInit.h
# opt/nvidia/nsight-systems/2020.3.2/target-linux-x64/nvtx/include/nvtx3/nvtxDetail/nvtxLinkOnce.h
# opt/nvidia/nsight-systems/2020.3.2/target-linux-x64/nvtx/include/nvtx3/nvtxDetail/nvtxImpl.h
# opt/nvidia/nsight-systems/2020.3.2/target-linux-x64/nvtx/include/nvtx3/nvtxDetail/nvtxInitDefs.h
# opt/nvidia/nsight-systems/2020.3.2/target-linux-x64/nvtx/include/nvtx3/nvtxDetail/nvtxImplSync_v3.h
# opt/nvidia/nsight-systems/2020.3.2/target-linux-x64/nvtx/include/nvtx3/nvToolsExtCuda.h
# opt/nvidia/nsight-systems/2020.3.2/target-linux-x64/nvtx/include/nvtx3/nvToolsExtOpenCL.h
# opt/nvidia/nsight-systems/2020.3.2/target-linux-x64/nvtx/include/nvtx3/nvToolsExtCudaRt.h
# opt/nvidia/nsight-systems/2020.3.2/target-linux-x64/nvtx/include/nvtx3/nvToolsExt.h
# opt/nvidia/nsight-systems/2020.3.2/target-linux-x64/nvtx/include/nvtx3/nvToolsExtSync.h
# opt/nvidia/nsight-systems/2020.3.2/target-linux-x64/libToolsInjectionCuBLAS64_9_0.so
# opt/nvidia/nsight-systems/2020.3.2/target-linux-x64/libToolsInjectionCuDNN64_7_0.so
# opt/nvidia/nsight-systems/2020.3.2/target-linux-x64/libToolsInjectionCuDNN64_7_6.so
# opt/nvidia/nsight-systems/2020.3.2/target-linux-x64/libcupti.so.10.1
# opt/nvidia/nsight-systems/2020.3.2/target-linux-x64/libToolsInjectionCudaInt64_9_1.so
# opt/nvidia/nsight-systems/2020.3.2/target-linux-x64/cudaAPISummary
# opt/nvidia/nsight-systems/2020.3.2/target-linux-x64/libToolsInjectionCuDNN64_7_4.so
# opt/nvidia/nsight-systems/2020.3.2/target-linux-x64/libToolsInjectionCuDNN64_8_0.so
# opt/nvidia/nsight-systems/2020.3.2/target-linux-x64/nsys-launcher
# opt/nvidia/nsight-systems/2020.3.2/target-linux-x64/libToolsInjectionCuBLAS64_9_2.so
# opt/nvidia/nsight-systems/2020.3.2/target-linux-x64/libToolsInjectionCuBLAS64_10_1.so
# opt/nvidia/nsight-systems/2020.3.2/target-linux-x64/libToolsInjectionCuBLAS64_10_0.so
# opt/nvidia/nsight-systems/2020.3.2/target-linux-x64/sqlite3
# opt/nvidia/nsight-systems/2020.3.2/target-linux-x64/libToolsInjectionCudaInt64_9_0.so
# opt/nvidia/nsight-systems/2020.3.2/documentation/
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/overview.html
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/search.html
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/index.html
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/.buildinfo
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/searchindex.js
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/genindex.html
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/examples.html
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/objects.inv
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/exported_data.html
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/json_text_format.html
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/ajax-loader.gif
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/up-pressed.png
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/up.png
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/stub.dx12.h5dump
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/fecs.gpuctxsw.results.txt
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/stub.report32.h5dump
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/conf.py
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/stub.sli.h5dump
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/down-pressed.png
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/underscore.js
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/sli.report109.sql
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/syscall_histogram.ftrace.results.txt
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/doctools.js
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/fps_histogram.dx12.results.txt
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/origin.simpleCudaGraphs.results.txt
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/websupport.js
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/composite.report32.results.txt
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/sched.report32.sql
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/fecs.gpuctxsw.sql
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/gpuctxsw.qdrep
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/comment-bright.png
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/report32.qdrep
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/map.cunvtx.results.txt
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/examples.rst
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/sli.report109.results.txt
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/cuda_kernel_api.report32.sql
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/cuda_kernel_api.report32.results.txt
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/basic.css
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/func_table.report32.results.txt
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/func_table.report32.sql
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/exported_data.rst
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/CMakeLists.txt
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/comment.png
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/json_text_format.rst
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/osrt.report32.results.txt
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/cunvtx.qdrep
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/composite.report32.sql
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/fps_histogram.dx12.sql
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/down.png
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/streams.report32.results.txt
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/ftrace.qdrep
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/file.png
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/overhead.report32.sql
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/map.cunvtx.sql
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/pygments.css
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/underscore-1.3.1.js
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/extract_jsonl.ftrace.results.txt
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/sidebar.js
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/overview.rst
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/simpleCudaGraphs.qdrep
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/sched.report32.results.txt
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/osrt.report32.sql
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/stub.cunvtx.h5dump
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/streams.report32.sql
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/dx12.qdrep
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/searchtools.js
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/plus.png
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/jquery.js
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/stub.ftrace.h5dump
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/origin.simpleCudaGraphs.sql
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/syscall_histogram.ftrace.sql
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/classic.css
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/custom.css
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/index.rst
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/stub.gpuctxsw.h5dump
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/comment-close.png
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/minus.png
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/overhead.report32.results.txt
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/jquery-3.1.0.js
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/extract_jsonl.ftrace.sql
# opt/nvidia/nsight-systems/2020.3.2/documentation/nsys-exporter/_static/report109.qdrep
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/Mesa/
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/Mesa/libGL.so.1.5.0
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/Mesa/libGL.so
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/Mesa/libGL.so.1
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/libicudata.so.56
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/libProtobufCommClient.so
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/libInjectionCommunicator.so
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/libboost_program_options.so.1.70.0
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/libStreamSections.so
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/libInterfaceSharedBase.so
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/libQt5WebEngineWidgets.so.5
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/libQt5Widgets.so.5
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/libQt5QuickWidgets.so.5
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/libQt5WebEngine.so.5
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/libInterfaceSharedCore.so
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/libcrypto.so
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/translations/
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/translations/qtwebengine_locales/
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/translations/qtwebengine_locales/es.pak
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/translations/qtwebengine_locales/bg.pak
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/translations/qtwebengine_locales/lt.pak
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/translations/qtwebengine_locales/sw.pak
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/translations/qtwebengine_locales/el.pak
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/translations/qtwebengine_locales/sl.pak
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/translations/qtwebengine_locales/th.pak
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/translations/qtwebengine_locales/ko.pak
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/translations/qtwebengine_locales/am.pak
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/translations/qtwebengine_locales/ro.pak
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/translations/qtwebengine_locales/vi.pak
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/translations/qtwebengine_locales/zh-TW.pak
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/translations/qtwebengine_locales/hi.pak
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/translations/qtwebengine_locales/mr.pak
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/translations/qtwebengine_locales/pt-PT.pak
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/translations/qtwebengine_locales/ca.pak
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/translations/qtwebengine_locales/en-US.pak
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/translations/qtwebengine_locales/es-419.pak
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/translations/qtwebengine_locales/lv.pak
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/translations/qtwebengine_locales/ru.pak
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/translations/qtwebengine_locales/hu.pak
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/translations/qtwebengine_locales/et.pak
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/translations/qtwebengine_locales/fi.pak
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/translations/qtwebengine_locales/uk.pak
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/translations/qtwebengine_locales/fil.pak
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/translations/qtwebengine_locales/da.pak
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/translations/qtwebengine_locales/ja.pak
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/translations/qtwebengine_locales/fa.pak
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/translations/qtwebengine_locales/ta.pak
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/translations/qtwebengine_locales/te.pak
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/translations/qtwebengine_locales/id.pak
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/translations/qtwebengine_locales/sk.pak
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/translations/qtwebengine_locales/gu.pak
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/translations/qtwebengine_locales/kn.pak
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/translations/qtwebengine_locales/pt-BR.pak
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/translations/qtwebengine_locales/fr.pak
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/translations/qtwebengine_locales/de.pak
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/translations/qtwebengine_locales/pl.pak
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/translations/qtwebengine_locales/it.pak
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/translations/qtwebengine_locales/sr.pak
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/translations/qtwebengine_locales/tr.pak
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/translations/qtwebengine_locales/nb.pak
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/translations/qtwebengine_locales/sv.pak
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/translations/qtwebengine_locales/zh-CN.pak
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/translations/qtwebengine_locales/nl.pak
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/translations/qtwebengine_locales/bn.pak
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/translations/qtwebengine_locales/ar.pak
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/translations/qtwebengine_locales/hr.pak
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/translations/qtwebengine_locales/ms.pak
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/translations/qtwebengine_locales/he.pak
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/translations/qtwebengine_locales/cs.pak
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/translations/qtwebengine_locales/ml.pak
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/translations/qtwebengine_locales/en-GB.pak
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/libQt5OpenGL.so.5
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/nsys-ui
# opt/nvidia/nsight-systems/2020.3.2/host-linux-x64/libstdc++.so.6
# ^C
# /

# %% [markdown]
# ## Visualization

# %%
import matplotlib.pyplot as plt

classes = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

plt.figure(figsize=(10, 20))
cnt = 0
for i, cls_name in enumerate(classes):
    path = f'{cls_name}/{cls_name}1.png'
    # benign image
    cnt += 1
    plt.subplot(len(classes), 4, cnt)
    im = Image.open(f'./data/{path}')
    logit = model(transform(im).unsqueeze(0).to(device))[0]
    predict = logit.argmax(-1).item()
    prob = logit.softmax(-1)[predict].item()
    plt.title(f'benign: {cls_name}1.png\n{classes[predict]}: {prob:.2%}')
    plt.axis('off')
    plt.imshow(np.array(im))
    # adversarial image
    cnt += 1
    plt.subplot(len(classes), 4, cnt)
    im = Image.open(f'./fgsm/{path}')
    logit = model(transform(im).unsqueeze(0).to(device))[0]
    predict = logit.argmax(-1).item()
    prob = logit.softmax(-1)[predict].item()
    plt.title(f'adversarial: {cls_name}1.png\n{classes[predict]}: {prob:.2%}')
    plt.axis('off')
    plt.imshow(np.array(im))
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-5d5b8cd7b95e> in <module>()
#      20     cnt += 1
#      21     plt.subplot(len(classes), 4, cnt)
# ---> 22     im = Image.open(f'./fgsm/{path}')
#      23     logit = model(transform(im).unsqueeze(0).to(device))[0]
#      24     predict = logit.argmax(-1).item()
#
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py in open(fp, mode)
#    2841
#    2842     if filename:
# -> 2843         fp = builtins.open(filename, "rb")
#    2844         exclusive_fp = True
#    2845
#
# FileNotFoundError: [Errno 2] No such file or directory: './fgsm/airplane/airplane1.png'

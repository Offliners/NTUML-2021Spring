# %% [markdown]
# <a href="https://colab.research.google.com/github/Offliners/NTUML2021_Hung-yi-Lee/blob/main/HW1/homework1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Homework 1: COVID-19 Cases Prediction (Regression)**
#
# Source: Delphi group @ CMU : A daily survey since April 2020 via facebook.

# %% [markdown]
# ## **Download Data**

# %%
tr_path = 'covid.train.csv'  # path to training data
tt_path = 'covid.test.csv'   # path to testing data

# !gdown --id '19CCyCgJrUxtvgZF53vnctJiOJ23T5mqF' --output covid.train.csv
# !gdown --id '1CE240jLm2npU-tdz81-oVKEF3T2yfT1O' --output covid.test.csv
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=19CCyCgJrUxtvgZF53vnctJiOJ23T5mqF
# To: /content/covid.train.csv
# 100% 2.00M/2.00M [00:00<00:00, 63.1MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1CE240jLm2npU-tdz81-oVKEF3T2yfT1O
# To: /content/covid.test.csv
# 100% 651k/651k [00:00<00:00, 42.9MB/s]

# %% [markdown]
# ## **Import Some Packages**

# %%
# PyTorch
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

# For data preprocess
import numpy as np
import csv
import os

# For plotting
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

myseed = 42069  # set a random seed for reproducibility
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(myseed)
torch.manual_seed(myseed)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(myseed)

# %% [markdown]
# ## **Some Utilities**

# %%
def get_device():
    ''' Get device (if GPU is available, use GPU) '''
    return 'cuda' if torch.cuda.is_available() else 'cpu'

def plot_learning_curve(loss_record, title=''):
    ''' Plot learning curve of your DNN (train & dev loss) '''
    total_steps = len(loss_record['train'])
    x_1 = range(total_steps)
    x_2 = x_1[::len(loss_record['train']) // len(loss_record['dev'])]
    figure(figsize=(6, 4))
    plt.plot(x_1, loss_record['train'], c='tab:red', label='train')
    plt.plot(x_2, loss_record['dev'], c='tab:cyan', label='dev')
    plt.ylim(0.0, 5.)
    plt.xlabel('Training steps')
    plt.ylabel('MSE loss')
    plt.title('Learning curve of {}'.format(title))
    plt.legend()
    plt.grid()
    plt.show()


def plot_pred(dv_set, model, device, lim=35., preds=None, targets=None):
    ''' Plot prediction of your DNN '''
    if preds is None or targets is None:
        model.eval()
        preds, targets = [], []
        for x, y in dv_set:
            x, y = x.to(device), y.to(device)
            with torch.no_grad():
                pred = model(x)
                preds.append(pred.detach().cpu())
                targets.append(y.detach().cpu())
        preds = torch.cat(preds, dim=0).numpy()
        targets = torch.cat(targets, dim=0).numpy()

    figure(figsize=(5, 5))
    plt.scatter(targets, preds, c='r', alpha=0.5)
    plt.plot([-0.2, lim], [-0.2, lim], c='b')
    plt.xlim(-0.2, lim)
    plt.ylim(-0.2, lim)
    plt.xlabel('ground truth value')
    plt.ylabel('predicted value')
    plt.title('Ground Truth v.s. Prediction')
    plt.grid()
    plt.show()

# %% [markdown]
# ## **Preprocess**
#
# We have three kinds of datasets:
# * `train`: for training
# * `dev`: for validation
# * `test`: for testing (w/o target value)
#
# ## **Dataset**
#
# The `COVID19Dataset` below does:
# * read `.csv` files
# * extract features
# * split `covid.train.csv` into train/dev sets
# * normalize features

# %%
class COVID19Dataset(Dataset):
    ''' Dataset for loading and preprocessing the COVID19 dataset '''
    def __init__(self,
                 path,
                 mode='train',
                 target_only=False):
        self.mode = mode

        # Read data into numpy arrays
        with open(path, 'r') as fp:
            data = list(csv.reader(fp))
            data = np.array(data[1:])[:, 1:].astype(float)
        
        if not target_only:
            feats = list(range(93))
        else:
            # TODO: Using 40 states & 2 tested_positive features (indices = 57 & 75)
            feats = list(range(40)) + [40, 41, 42, 43, 57, 58, 59, 60, 61, 75, 76, 77, 78, 79]
            pass

        if mode == 'test':
            # Testing data
            # data: 893 x 93 (40 states + day 1 (18) + day 2 (18) + day 3 (17))
            data = data[:, feats]
            self.data = torch.FloatTensor(data)
        else:
            # Training data (train/dev sets)
            # data: 2700 x 94 (40 states + day 1 (18) + day 2 (18) + day 3 (18))
            target = data[:, -1]
            data = data[:, feats]
            
            # Splitting training data into train & dev sets
            if mode == 'train':
                indices = [i for i in range(len(data)) if i % 10 != 0]
            elif mode == 'dev':
                indices = [i for i in range(len(data)) if i % 10 == 0]
            
            # Convert data into PyTorch tensors
            self.data = torch.FloatTensor(data[indices])
            self.target = torch.FloatTensor(target[indices])

        # Normalize features (you may remove this part to see what will happen)
        self.data[:, 40:] = \
            (self.data[:, 40:] - self.data[:, 40:].mean(dim=0, keepdim=True)) \
            / self.data[:, 40:].std(dim=0, keepdim=True)

        self.dim = self.data.shape[1]

        print('Finished reading the {} set of COVID19 Dataset ({} samples found, each dim = {})'
              .format(mode, len(self.data), self.dim))

    def __getitem__(self, index):
        # Returns one sample at a time
        if self.mode in ['train', 'dev']:
            # For training
            return self.data[index], self.target[index]
        else:
            # For testing (no target)
            return self.data[index]

    def __len__(self):
        # Returns the size of the dataset
        return len(self.data)

# %% [markdown]
# ## **DataLoader**
#
# A `DataLoader` loads data from a given `Dataset` into batches.

# %%
def prep_dataloader(path, mode, batch_size, n_jobs=0, target_only=False):
    ''' Generates a dataset, then is put into a dataloader. '''
    dataset = COVID19Dataset(path, mode=mode, target_only=target_only)  # Construct dataset
    dataloader = DataLoader(
        dataset, batch_size,
        shuffle=(mode == 'train'), drop_last=False,
        num_workers=n_jobs, pin_memory=True)                            # Construct dataloader
    return dataloader

# %% [markdown]
# ## **Deep Neural Network**
#
# `NeuralNet` is an `nn.Module` designed for regression.
# The DNN consists of 2 fully-connected layers with ReLU activation.
# This module also included a function `cal_loss` for calculating loss.

# %%
class NeuralNet(nn.Module):
    ''' A simple fully-connected deep neural network '''
    def __init__(self, input_dim):
        super(NeuralNet, self).__init__()

        # Define your neural network here
        # TODO: How to modify this model to achieve better performance?
        self.net = nn.Sequential(
            nn.Linear(input_dim, 64),
            nn.ReLU(),
            nn.Linear(64, 64),
            nn.ReLU(),
            nn.Linear(64, 1)
        )

        # Mean squared error loss
        self.criterion = nn.MSELoss(reduction='mean')

    def forward(self, x):
        ''' Given input of size (batch_size x input_dim), compute output of the network '''
        return self.net(x).squeeze(1)

    def cal_loss(self, pred, target):
        ''' Calculate loss '''
        # TODO: you may implement L2 regularization here

        return self.criterion(pred, target)

# %% [markdown]
# ## **Training**

# %%
def train(tr_set, dv_set, model, config, device):
    ''' DNN training '''

    n_epochs = config['n_epochs']  # Maximum number of epochs

    # Setup optimizer
    optimizer = getattr(torch.optim, config['optimizer'])(
        model.parameters(), **config['optim_hparas'])

    min_mse = 1000.
    loss_record = {'train': [], 'dev': []}      # for recording training loss
    early_stop_cnt = 0
    epoch = 0
    while epoch < n_epochs:
        model.train()                           # set model to training mode
        for x, y in tr_set:                     # iterate through the dataloader
            optimizer.zero_grad()               # set gradient to zero
            x, y = x.to(device), y.to(device)   # move data to device (cpu/cuda)
            pred = model(x)                     # forward pass (compute output)
            mse_loss = model.cal_loss(pred, y)  # compute loss
            mse_loss.backward()                 # compute gradient (backpropagation)
            optimizer.step()                    # update model with optimizer
            loss_record['train'].append(mse_loss.detach().cpu().item())

        # After each epoch, test your model on the validation (development) set.
        dev_mse = dev(dv_set, model, device)
        if dev_mse < min_mse:
            # Save model if your model improved
            min_mse = dev_mse
            print('Saving model (epoch = {:4d}, loss = {:.4f})'
                .format(epoch + 1, min_mse))
            torch.save(model.state_dict(), config['save_path'])  # Save model to specified path
            early_stop_cnt = 0
        else:
            early_stop_cnt += 1

        epoch += 1
        loss_record['dev'].append(dev_mse)
        if early_stop_cnt > config['early_stop']:
            # Stop training if your model stops improving for "config['early_stop']" epochs.
            break

    print('Finished training after {} epochs'.format(epoch))
    return min_mse, loss_record

# %% [markdown]
# ## **Validation**

# %%
def dev(dv_set, model, device):
    model.eval()                                # set model to evalutation mode
    total_loss = 0
    for x, y in dv_set:                         # iterate through the dataloader
        x, y = x.to(device), y.to(device)       # move data to device (cpu/cuda)
        with torch.no_grad():                   # disable gradient calculation
            pred = model(x)                     # forward pass (compute output)
            mse_loss = model.cal_loss(pred, y)  # compute loss
        total_loss += mse_loss.detach().cpu().item() * len(x)  # accumulate loss
    total_loss = total_loss / len(dv_set.dataset)              # compute averaged loss

    return total_loss

# %% [markdown]
# ## **Testing**

# %%
def test(tt_set, model, device):
    model.eval()                                # set model to evalutation mode
    preds = []
    for x in tt_set:                            # iterate through the dataloader
        x = x.to(device)                        # move data to device (cpu/cuda)
        with torch.no_grad():                   # disable gradient calculation
            pred = model(x)                     # forward pass (compute output)
            preds.append(pred.detach().cpu())   # collect prediction
    preds = torch.cat(preds, dim=0).numpy()     # concatenate all predictions and convert to a numpy array
    return preds

# %% [markdown]
# ## **Setup Hyper-parameters**
# `config` contains hyper-parameters for training and the path to save your model.

# %%
device = get_device()                 # get the current available device ('cpu' or 'cuda')
os.makedirs('models', exist_ok=True)  # The trained model will be saved to ./models/
target_only = True                    # TODO: Using 40 states & 2 tested_positive features

# TODO: How to tune these hyper-parameters to improve your model's performance?
config = {
    'n_epochs': 20000,               # maximum number of epochs
    'batch_size': 200,               # mini-batch size for dataloader
    'optimizer': 'SGD',              # optimization algorithm (optimizer in torch.optim)
    'optim_hparas': {                # hyper-parameters for the optimizer (depends on which optimizer you are using)
        'lr': 0.00001,               # learning rate of SGD
        'momentum': 0.9,             # momentum for SGD
        'weight_decay': 0.00001
    },
    'early_stop': 200,               # early stopping epochs (the number epochs since your model's last improvement)
    'save_path': 'models/model.pth'  # your model will be saved here
}

# %% [markdown]
# ## **Load data and model**

# %%
tr_set = prep_dataloader(tr_path, 'train', config['batch_size'], target_only=target_only)
dv_set = prep_dataloader(tr_path, 'dev', config['batch_size'], target_only=target_only)
tt_set = prep_dataloader(tt_path, 'test', config['batch_size'], target_only=target_only)

model = NeuralNet(tr_set.dataset.dim).to(device)  # Construct model and move to device
# Out:
# Finished reading the train set of COVID19 Dataset (2430 samples found, each dim = 54)
# Finished reading the dev set of COVID19 Dataset (270 samples found, each dim = 54)
# Finished reading the test set of COVID19 Dataset (893 samples found, each dim = 54)

# %% [markdown]
# ## **Start Training!**

# %%
model_loss, model_loss_record = train(tr_set, dv_set, model, config, device)
# Out:
# Saving model (epoch =    1, loss = 324.7942)
# Saving model (epoch =    2, loss = 322.4546)
# Saving model (epoch =    3, loss = 319.8061)
# Saving model (epoch =    4, loss = 317.0981)
# Saving model (epoch =    5, loss = 314.3330)
# Saving model (epoch =    6, loss = 311.5094)
# Saving model (epoch =    7, loss = 308.5813)
# Saving model (epoch =    8, loss = 305.4027)
# Saving model (epoch =    9, loss = 301.9792)
# Saving model (epoch =   10, loss = 298.2133)
# Saving model (epoch =   11, loss = 294.0180)
# Saving model (epoch =   12, loss = 289.2887)
# Saving model (epoch =   13, loss = 284.0232)
# Saving model (epoch =   14, loss = 277.9617)
# Saving model (epoch =   15, loss = 270.8302)
# Saving model (epoch =   16, loss = 262.3114)
# Saving model (epoch =   17, loss = 252.2490)
# Saving model (epoch =   18, loss = 240.1433)
# Saving model (epoch =   19, loss = 225.4568)
# Saving model (epoch =   20, loss = 208.0254)
# Saving model (epoch =   21, loss = 187.6484)
# Saving model (epoch =   22, loss = 165.1527)
# Saving model (epoch =   23, loss = 140.9097)
# Saving model (epoch =   24, loss = 117.9299)
# Saving model (epoch =   25, loss = 98.6955)
# Saving model (epoch =   26, loss = 84.8207)
# Saving model (epoch =   27, loss = 76.5184)
# Saving model (epoch =   28, loss = 71.9959)
# Saving model (epoch =   29, loss = 69.2905)
# Saving model (epoch =   30, loss = 67.1858)
# Saving model (epoch =   31, loss = 65.2365)
# Saving model (epoch =   32, loss = 63.3430)
# Saving model (epoch =   33, loss = 61.4660)
# Saving model (epoch =   34, loss = 59.6130)
# Saving model (epoch =   35, loss = 57.7993)
# Saving model (epoch =   36, loss = 56.0142)
# Saving model (epoch =   37, loss = 54.2929)
# Saving model (epoch =   38, loss = 52.5758)
# Saving model (epoch =   39, loss = 50.9349)
# Saving model (epoch =   40, loss = 49.3458)
# Saving model (epoch =   41, loss = 47.8132)
# Saving model (epoch =   42, loss = 46.3103)
# Saving model (epoch =   43, loss = 44.8786)
# Saving model (epoch =   44, loss = 43.4543)
# Saving model (epoch =   45, loss = 42.1004)
# Saving model (epoch =   46, loss = 40.7855)
# Saving model (epoch =   47, loss = 39.5117)
# Saving model (epoch =   48, loss = 38.2512)
# Saving model (epoch =   49, loss = 37.0246)
# Saving model (epoch =   50, loss = 35.8289)
# Saving model (epoch =   51, loss = 34.6441)
# Saving model (epoch =   52, loss = 33.4918)
# Saving model (epoch =   53, loss = 32.3535)
# Saving model (epoch =   54, loss = 31.2200)
# Saving model (epoch =   55, loss = 30.0649)
# Saving model (epoch =   56, loss = 28.9069)
# Saving model (epoch =   57, loss = 27.7478)
# Saving model (epoch =   58, loss = 26.6102)
# Saving model (epoch =   59, loss = 25.4844)
# Saving model (epoch =   60, loss = 24.3656)
# Saving model (epoch =   61, loss = 23.2364)
# Saving model (epoch =   62, loss = 22.1417)
# Saving model (epoch =   63, loss = 21.0802)
# Saving model (epoch =   64, loss = 20.0281)
# Saving model (epoch =   65, loss = 18.9990)
# Saving model (epoch =   66, loss = 17.9967)
# Saving model (epoch =   67, loss = 17.0184)
# Saving model (epoch =   68, loss = 16.0849)
# Saving model (epoch =   69, loss = 15.2067)
# Saving model (epoch =   70, loss = 14.3576)
# Saving model (epoch =   71, loss = 13.5425)
# Saving model (epoch =   72, loss = 12.7808)
# Saving model (epoch =   73, loss = 12.0618)
# Saving model (epoch =   74, loss = 11.3911)
# Saving model (epoch =   75, loss = 10.7801)
# Saving model (epoch =   76, loss = 10.2061)
# Saving model (epoch =   77, loss = 9.6579)
# Saving model (epoch =   78, loss = 9.1507)
# Saving model (epoch =   79, loss = 8.6802)
# Saving model (epoch =   80, loss = 8.2394)
# Saving model (epoch =   81, loss = 7.8228)
# Saving model (epoch =   82, loss = 7.4305)
# Saving model (epoch =   83, loss = 7.0650)
# Saving model (epoch =   84, loss = 6.7228)
# Saving model (epoch =   85, loss = 6.4166)
# Saving model (epoch =   86, loss = 6.1229)
# Saving model (epoch =   87, loss = 5.8483)
# Saving model (epoch =   88, loss = 5.5891)
# Saving model (epoch =   89, loss = 5.3609)
# Saving model (epoch =   90, loss = 5.1474)
# Saving model (epoch =   91, loss = 4.9479)
# Saving model (epoch =   92, loss = 4.7518)
# Saving model (epoch =   93, loss = 4.5777)
# Saving model (epoch =   94, loss = 4.4184)
# Saving model (epoch =   95, loss = 4.2676)
# Saving model (epoch =   96, loss = 4.1208)
# Saving model (epoch =   97, loss = 3.9833)
# Saving model (epoch =   98, loss = 3.8547)
# Saving model (epoch =   99, loss = 3.7352)
# Saving model (epoch =  100, loss = 3.6218)
# Saving model (epoch =  101, loss = 3.5201)
# Saving model (epoch =  102, loss = 3.4114)
# Saving model (epoch =  103, loss = 3.3130)
# Saving model (epoch =  104, loss = 3.2203)
# Saving model (epoch =  105, loss = 3.1364)
# Saving model (epoch =  106, loss = 3.0607)
# Saving model (epoch =  107, loss = 2.9943)
# Saving model (epoch =  108, loss = 2.9014)
# Saving model (epoch =  109, loss = 2.8190)
# Saving model (epoch =  110, loss = 2.7481)
# Saving model (epoch =  111, loss = 2.6846)
# Saving model (epoch =  112, loss = 2.6209)
# Saving model (epoch =  113, loss = 2.5644)
# Saving model (epoch =  114, loss = 2.5109)
# Saving model (epoch =  115, loss = 2.4530)
# Saving model (epoch =  116, loss = 2.3948)
# Saving model (epoch =  117, loss = 2.3453)
# Saving model (epoch =  118, loss = 2.2965)
# Saving model (epoch =  119, loss = 2.2493)
# Saving model (epoch =  120, loss = 2.2056)
# Saving model (epoch =  121, loss = 2.1635)
# Saving model (epoch =  122, loss = 2.1218)
# Saving model (epoch =  123, loss = 2.0852)
# Saving model (epoch =  124, loss = 2.0504)
# Saving model (epoch =  125, loss = 2.0173)
# Saving model (epoch =  126, loss = 1.9839)
# Saving model (epoch =  127, loss = 1.9526)
# Saving model (epoch =  128, loss = 1.9215)
# Saving model (epoch =  129, loss = 1.8915)
# Saving model (epoch =  130, loss = 1.8711)
# Saving model (epoch =  131, loss = 1.8376)
# Saving model (epoch =  132, loss = 1.8054)
# Saving model (epoch =  133, loss = 1.7797)
# Saving model (epoch =  134, loss = 1.7578)
# Saving model (epoch =  135, loss = 1.7368)
# Saving model (epoch =  136, loss = 1.7107)
# Saving model (epoch =  137, loss = 1.6907)
# Saving model (epoch =  138, loss = 1.6703)
# Saving model (epoch =  139, loss = 1.6498)
# Saving model (epoch =  140, loss = 1.6329)
# Saving model (epoch =  141, loss = 1.6161)
# Saving model (epoch =  142, loss = 1.6021)
# Saving model (epoch =  143, loss = 1.5854)
# Saving model (epoch =  144, loss = 1.5636)
# Saving model (epoch =  145, loss = 1.5503)
# Saving model (epoch =  146, loss = 1.5331)
# Saving model (epoch =  147, loss = 1.5189)
# Saving model (epoch =  148, loss = 1.5045)
# Saving model (epoch =  149, loss = 1.4935)
# Saving model (epoch =  150, loss = 1.4816)
# Saving model (epoch =  151, loss = 1.4714)
# Saving model (epoch =  152, loss = 1.4609)
# Saving model (epoch =  153, loss = 1.4498)
# Saving model (epoch =  154, loss = 1.4382)
# Saving model (epoch =  155, loss = 1.4288)
# Saving model (epoch =  156, loss = 1.4163)
# Saving model (epoch =  157, loss = 1.4092)
# Saving model (epoch =  158, loss = 1.4024)
# Saving model (epoch =  159, loss = 1.3906)
# Saving model (epoch =  160, loss = 1.3806)
# Saving model (epoch =  161, loss = 1.3708)
# Saving model (epoch =  162, loss = 1.3640)
# Saving model (epoch =  163, loss = 1.3568)
# Saving model (epoch =  164, loss = 1.3505)
# Saving model (epoch =  165, loss = 1.3448)
# Saving model (epoch =  166, loss = 1.3390)
# Saving model (epoch =  167, loss = 1.3313)
# Saving model (epoch =  168, loss = 1.3233)
# Saving model (epoch =  169, loss = 1.3154)
# Saving model (epoch =  170, loss = 1.3105)
# Saving model (epoch =  171, loss = 1.3040)
# Saving model (epoch =  172, loss = 1.3012)
# Saving model (epoch =  173, loss = 1.3001)
# Saving model (epoch =  174, loss = 1.2941)
# Saving model (epoch =  175, loss = 1.2848)
# Saving model (epoch =  176, loss = 1.2783)
# Saving model (epoch =  177, loss = 1.2761)
# Saving model (epoch =  178, loss = 1.2709)
# Saving model (epoch =  179, loss = 1.2660)
# Saving model (epoch =  180, loss = 1.2632)
# Saving model (epoch =  181, loss = 1.2574)
# Saving model (epoch =  182, loss = 1.2558)
# Saving model (epoch =  183, loss = 1.2521)
# Saving model (epoch =  184, loss = 1.2469)
# Saving model (epoch =  185, loss = 1.2436)
# Saving model (epoch =  186, loss = 1.2379)
# Saving model (epoch =  187, loss = 1.2353)
# Saving model (epoch =  188, loss = 1.2335)
# Saving model (epoch =  189, loss = 1.2306)
# Saving model (epoch =  190, loss = 1.2252)
# Saving model (epoch =  191, loss = 1.2214)
# Saving model (epoch =  192, loss = 1.2185)
# Saving model (epoch =  193, loss = 1.2175)
# Saving model (epoch =  194, loss = 1.2168)
# Saving model (epoch =  195, loss = 1.2145)
# Saving model (epoch =  196, loss = 1.2095)
# Saving model (epoch =  197, loss = 1.2065)
# Saving model (epoch =  198, loss = 1.2042)
# Saving model (epoch =  199, loss = 1.2019)
# Saving model (epoch =  200, loss = 1.1988)
# Saving model (epoch =  201, loss = 1.1962)
# Saving model (epoch =  202, loss = 1.1940)
# Saving model (epoch =  203, loss = 1.1928)
# Saving model (epoch =  204, loss = 1.1872)
# Saving model (epoch =  205, loss = 1.1850)
# Saving model (epoch =  207, loss = 1.1838)
# Saving model (epoch =  208, loss = 1.1796)
# Saving model (epoch =  209, loss = 1.1771)
# Saving model (epoch =  210, loss = 1.1751)
# Saving model (epoch =  211, loss = 1.1739)
# Saving model (epoch =  212, loss = 1.1709)
# Saving model (epoch =  213, loss = 1.1705)
# Saving model (epoch =  214, loss = 1.1682)
# Saving model (epoch =  215, loss = 1.1650)
# Saving model (epoch =  216, loss = 1.1641)
# Saving model (epoch =  220, loss = 1.1601)
# Saving model (epoch =  221, loss = 1.1552)
# Saving model (epoch =  224, loss = 1.1533)
# Saving model (epoch =  225, loss = 1.1499)
# Saving model (epoch =  226, loss = 1.1499)
# Saving model (epoch =  227, loss = 1.1498)
# Saving model (epoch =  228, loss = 1.1490)
# Saving model (epoch =  229, loss = 1.1457)
# Saving model (epoch =  230, loss = 1.1406)
# Saving model (epoch =  231, loss = 1.1401)
# Saving model (epoch =  233, loss = 1.1396)
# Saving model (epoch =  235, loss = 1.1375)
# Saving model (epoch =  236, loss = 1.1359)
# Saving model (epoch =  237, loss = 1.1343)
# Saving model (epoch =  238, loss = 1.1315)
# Saving model (epoch =  239, loss = 1.1294)
# Saving model (epoch =  242, loss = 1.1291)
# Saving model (epoch =  243, loss = 1.1274)
# Saving model (epoch =  244, loss = 1.1254)
# Saving model (epoch =  245, loss = 1.1252)
# Saving model (epoch =  246, loss = 1.1250)
# Saving model (epoch =  249, loss = 1.1215)
# Saving model (epoch =  251, loss = 1.1213)
# Saving model (epoch =  253, loss = 1.1204)
# Saving model (epoch =  254, loss = 1.1160)
# Saving model (epoch =  255, loss = 1.1153)
# Saving model (epoch =  258, loss = 1.1144)
# Saving model (epoch =  261, loss = 1.1117)
# Saving model (epoch =  262, loss = 1.1091)
# Saving model (epoch =  266, loss = 1.1078)
# Saving model (epoch =  267, loss = 1.1054)
# Saving model (epoch =  268, loss = 1.1052)
# Saving model (epoch =  269, loss = 1.1021)
# Saving model (epoch =  270, loss = 1.0997)
# Saving model (epoch =  271, loss = 1.0994)
# Saving model (epoch =  274, loss = 1.0991)
# Saving model (epoch =  275, loss = 1.0957)
# Saving model (epoch =  276, loss = 1.0948)
# Saving model (epoch =  281, loss = 1.0940)
# Saving model (epoch =  282, loss = 1.0928)
# Saving model (epoch =  284, loss = 1.0920)
# Saving model (epoch =  285, loss = 1.0912)
# Saving model (epoch =  288, loss = 1.0888)
# Saving model (epoch =  289, loss = 1.0876)
# Saving model (epoch =  291, loss = 1.0874)
# Saving model (epoch =  292, loss = 1.0858)
# Saving model (epoch =  293, loss = 1.0836)
# Saving model (epoch =  294, loss = 1.0832)
# Saving model (epoch =  295, loss = 1.0816)
# Saving model (epoch =  298, loss = 1.0811)
# Saving model (epoch =  301, loss = 1.0793)
# Saving model (epoch =  302, loss = 1.0775)
# Saving model (epoch =  303, loss = 1.0759)
# Saving model (epoch =  304, loss = 1.0750)
# Saving model (epoch =  305, loss = 1.0747)
# Saving model (epoch =  307, loss = 1.0745)
# Saving model (epoch =  308, loss = 1.0735)
# Saving model (epoch =  310, loss = 1.0729)
# Saving model (epoch =  311, loss = 1.0707)
# Saving model (epoch =  312, loss = 1.0691)
# Saving model (epoch =  313, loss = 1.0677)
# Saving model (epoch =  315, loss = 1.0667)
# Saving model (epoch =  316, loss = 1.0666)
# Saving model (epoch =  323, loss = 1.0635)
# Saving model (epoch =  325, loss = 1.0617)
# Saving model (epoch =  326, loss = 1.0616)
# Saving model (epoch =  331, loss = 1.0608)
# Saving model (epoch =  332, loss = 1.0585)
# Saving model (epoch =  333, loss = 1.0569)
# Saving model (epoch =  335, loss = 1.0557)
# Saving model (epoch =  339, loss = 1.0540)
# Saving model (epoch =  342, loss = 1.0522)
# Saving model (epoch =  343, loss = 1.0517)
# Saving model (epoch =  344, loss = 1.0496)
# Saving model (epoch =  348, loss = 1.0486)
# Saving model (epoch =  349, loss = 1.0459)
# Saving model (epoch =  353, loss = 1.0445)
# Saving model (epoch =  354, loss = 1.0438)
# Saving model (epoch =  358, loss = 1.0434)
# Saving model (epoch =  359, loss = 1.0429)
# Saving model (epoch =  360, loss = 1.0428)
# Saving model (epoch =  363, loss = 1.0412)
# Saving model (epoch =  364, loss = 1.0393)
# Saving model (epoch =  365, loss = 1.0368)
# Saving model (epoch =  370, loss = 1.0338)
# Saving model (epoch =  371, loss = 1.0315)
# Saving model (epoch =  377, loss = 1.0309)
# Saving model (epoch =  381, loss = 1.0284)
# Saving model (epoch =  383, loss = 1.0273)
# Saving model (epoch =  388, loss = 1.0268)
# Saving model (epoch =  389, loss = 1.0266)
# Saving model (epoch =  390, loss = 1.0264)
# Saving model (epoch =  391, loss = 1.0248)
# Saving model (epoch =  397, loss = 1.0218)
# Saving model (epoch =  398, loss = 1.0207)
# Saving model (epoch =  400, loss = 1.0205)
# Saving model (epoch =  401, loss = 1.0198)
# Saving model (epoch =  404, loss = 1.0190)
# Saving model (epoch =  406, loss = 1.0179)
# Saving model (epoch =  409, loss = 1.0169)
# Saving model (epoch =  410, loss = 1.0156)
# Saving model (epoch =  413, loss = 1.0154)
# Saving model (epoch =  418, loss = 1.0150)
# Saving model (epoch =  420, loss = 1.0123)
# Saving model (epoch =  421, loss = 1.0110)
# Saving model (epoch =  425, loss = 1.0093)
# Saving model (epoch =  426, loss = 1.0071)
# Saving model (epoch =  427, loss = 1.0059)
# Saving model (epoch =  434, loss = 1.0049)
# Saving model (epoch =  435, loss = 1.0043)
# Saving model (epoch =  440, loss = 1.0014)
# Saving model (epoch =  449, loss = 1.0010)
# Saving model (epoch =  450, loss = 1.0005)
# Saving model (epoch =  454, loss = 0.9983)
# Saving model (epoch =  455, loss = 0.9981)
# Saving model (epoch =  456, loss = 0.9960)
# Saving model (epoch =  462, loss = 0.9952)
# Saving model (epoch =  463, loss = 0.9927)
# Saving model (epoch =  470, loss = 0.9912)
# Saving model (epoch =  475, loss = 0.9906)
# Saving model (epoch =  478, loss = 0.9903)
# Saving model (epoch =  479, loss = 0.9899)
# Saving model (epoch =  480, loss = 0.9883)
# Saving model (epoch =  489, loss = 0.9870)
# Saving model (epoch =  490, loss = 0.9860)
# Saving model (epoch =  491, loss = 0.9851)
# Saving model (epoch =  493, loss = 0.9840)
# Saving model (epoch =  498, loss = 0.9837)
# Saving model (epoch =  499, loss = 0.9821)
# Saving model (epoch =  500, loss = 0.9816)
# Saving model (epoch =  504, loss = 0.9814)
# Saving model (epoch =  505, loss = 0.9812)
# Saving model (epoch =  507, loss = 0.9804)
# Saving model (epoch =  510, loss = 0.9795)
# Saving model (epoch =  514, loss = 0.9777)
# Saving model (epoch =  515, loss = 0.9762)
# Saving model (epoch =  516, loss = 0.9754)
# Saving model (epoch =  519, loss = 0.9744)
# Saving model (epoch =  520, loss = 0.9741)
# Saving model (epoch =  530, loss = 0.9736)
# Saving model (epoch =  532, loss = 0.9724)
# Saving model (epoch =  540, loss = 0.9706)
# Saving model (epoch =  547, loss = 0.9700)
# Saving model (epoch =  551, loss = 0.9685)
# Saving model (epoch =  557, loss = 0.9661)
# Saving model (epoch =  558, loss = 0.9656)
# Saving model (epoch =  563, loss = 0.9654)
# Saving model (epoch =  567, loss = 0.9640)
# Saving model (epoch =  568, loss = 0.9635)
# Saving model (epoch =  572, loss = 0.9631)
# Saving model (epoch =  576, loss = 0.9619)
# Saving model (epoch =  577, loss = 0.9599)
# Saving model (epoch =  588, loss = 0.9593)
# Saving model (epoch =  589, loss = 0.9581)
# Saving model (epoch =  593, loss = 0.9578)
# Saving model (epoch =  596, loss = 0.9551)
# Saving model (epoch =  597, loss = 0.9538)
# Saving model (epoch =  598, loss = 0.9537)
# Saving model (epoch =  610, loss = 0.9534)
# Saving model (epoch =  614, loss = 0.9532)
# Saving model (epoch =  618, loss = 0.9527)
# Saving model (epoch =  619, loss = 0.9510)
# Saving model (epoch =  625, loss = 0.9509)
# Saving model (epoch =  626, loss = 0.9500)
# Saving model (epoch =  627, loss = 0.9486)
# Saving model (epoch =  636, loss = 0.9471)
# Saving model (epoch =  637, loss = 0.9469)
# Saving model (epoch =  644, loss = 0.9468)
# Saving model (epoch =  649, loss = 0.9451)
# Saving model (epoch =  653, loss = 0.9450)
# Saving model (epoch =  654, loss = 0.9446)
# Saving model (epoch =  657, loss = 0.9418)
# Saving model (epoch =  662, loss = 0.9405)
# Saving model (epoch =  663, loss = 0.9381)
# Saving model (epoch =  677, loss = 0.9379)
# Saving model (epoch =  683, loss = 0.9375)
# Saving model (epoch =  689, loss = 0.9361)
# Saving model (epoch =  705, loss = 0.9340)
# Saving model (epoch =  706, loss = 0.9330)
# Saving model (epoch =  712, loss = 0.9329)
# Saving model (epoch =  718, loss = 0.9319)
# Saving model (epoch =  724, loss = 0.9316)
# Saving model (epoch =  725, loss = 0.9307)
# Saving model (epoch =  726, loss = 0.9305)
# Saving model (epoch =  730, loss = 0.9302)
# Saving model (epoch =  731, loss = 0.9301)
# Saving model (epoch =  733, loss = 0.9300)
# Saving model (epoch =  737, loss = 0.9285)
# Saving model (epoch =  742, loss = 0.9273)
# Saving model (epoch =  750, loss = 0.9260)
# Saving model (epoch =  761, loss = 0.9257)
# Saving model (epoch =  762, loss = 0.9253)
# Saving model (epoch =  767, loss = 0.9238)
# Saving model (epoch =  780, loss = 0.9227)
# Saving model (epoch =  785, loss = 0.9225)
# Saving model (epoch =  790, loss = 0.9221)
# Saving model (epoch =  791, loss = 0.9212)
# Saving model (epoch =  796, loss = 0.9205)
# Saving model (epoch =  806, loss = 0.9204)
# Saving model (epoch =  811, loss = 0.9199)
# Saving model (epoch =  814, loss = 0.9199)
# Saving model (epoch =  815, loss = 0.9198)
# Saving model (epoch =  816, loss = 0.9183)
# Saving model (epoch =  817, loss = 0.9180)
# Saving model (epoch =  820, loss = 0.9174)
# Saving model (epoch =  825, loss = 0.9173)
# Saving model (epoch =  829, loss = 0.9152)
# Saving model (epoch =  830, loss = 0.9142)
# Saving model (epoch =  834, loss = 0.9140)
# Saving model (epoch =  844, loss = 0.9126)
# Saving model (epoch =  851, loss = 0.9124)
# Saving model (epoch =  864, loss = 0.9122)
# Saving model (epoch =  867, loss = 0.9119)
# Saving model (epoch =  868, loss = 0.9106)
# Saving model (epoch =  880, loss = 0.9102)
# Saving model (epoch =  886, loss = 0.9092)
# Saving model (epoch =  889, loss = 0.9089)
# Saving model (epoch =  894, loss = 0.9077)
# Saving model (epoch =  911, loss = 0.9067)
# Saving model (epoch =  912, loss = 0.9065)
# Saving model (epoch =  913, loss = 0.9052)
# Saving model (epoch =  932, loss = 0.9047)
# Saving model (epoch =  936, loss = 0.9042)
# Saving model (epoch =  938, loss = 0.9041)
# Saving model (epoch =  939, loss = 0.9031)
# Saving model (epoch =  942, loss = 0.9023)
# Saving model (epoch =  950, loss = 0.9020)
# Saving model (epoch =  951, loss = 0.9003)
# Saving model (epoch =  952, loss = 0.8997)
# Saving model (epoch =  953, loss = 0.8997)
# Saving model (epoch =  966, loss = 0.8995)
# Saving model (epoch =  974, loss = 0.8990)
# Saving model (epoch =  975, loss = 0.8984)
# Saving model (epoch =  989, loss = 0.8975)
# Saving model (epoch =  997, loss = 0.8968)
# Saving model (epoch = 1009, loss = 0.8959)
# Saving model (epoch = 1010, loss = 0.8951)
# Saving model (epoch = 1021, loss = 0.8946)
# Saving model (epoch = 1043, loss = 0.8943)
# Saving model (epoch = 1044, loss = 0.8936)
# Saving model (epoch = 1056, loss = 0.8936)
# Saving model (epoch = 1057, loss = 0.8928)
# Saving model (epoch = 1060, loss = 0.8923)
# Saving model (epoch = 1063, loss = 0.8921)
# Saving model (epoch = 1069, loss = 0.8921)
# Saving model (epoch = 1070, loss = 0.8919)
# Saving model (epoch = 1074, loss = 0.8919)
# Saving model (epoch = 1075, loss = 0.8915)
# Saving model (epoch = 1076, loss = 0.8913)
# Saving model (epoch = 1079, loss = 0.8911)
# Saving model (epoch = 1080, loss = 0.8900)
# Saving model (epoch = 1086, loss = 0.8896)
# Saving model (epoch = 1089, loss = 0.8893)
# Saving model (epoch = 1096, loss = 0.8890)
# Saving model (epoch = 1102, loss = 0.8881)
# Saving model (epoch = 1103, loss = 0.8879)
# Saving model (epoch = 1111, loss = 0.8865)
# Saving model (epoch = 1124, loss = 0.8862)
# Saving model (epoch = 1127, loss = 0.8858)
# Saving model (epoch = 1128, loss = 0.8838)
# Saving model (epoch = 1172, loss = 0.8831)
# Saving model (epoch = 1174, loss = 0.8829)
# Saving model (epoch = 1182, loss = 0.8829)
# Saving model (epoch = 1183, loss = 0.8823)
# Saving model (epoch = 1189, loss = 0.8800)
# Saving model (epoch = 1212, loss = 0.8787)
# Saving model (epoch = 1226, loss = 0.8766)
# Saving model (epoch = 1258, loss = 0.8763)
# Saving model (epoch = 1272, loss = 0.8754)
# Saving model (epoch = 1301, loss = 0.8751)
# Saving model (epoch = 1302, loss = 0.8744)
# Saving model (epoch = 1303, loss = 0.8743)
# Saving model (epoch = 1319, loss = 0.8741)
# Saving model (epoch = 1320, loss = 0.8736)
# Saving model (epoch = 1333, loss = 0.8725)
# Saving model (epoch = 1335, loss = 0.8724)
# Saving model (epoch = 1353, loss = 0.8721)
# Saving model (epoch = 1357, loss = 0.8720)
# Saving model (epoch = 1362, loss = 0.8719)
# Saving model (epoch = 1363, loss = 0.8706)
# Saving model (epoch = 1369, loss = 0.8703)
# Saving model (epoch = 1398, loss = 0.8690)
# Saving model (epoch = 1418, loss = 0.8680)
# Saving model (epoch = 1419, loss = 0.8673)
# Saving model (epoch = 1424, loss = 0.8667)
# Saving model (epoch = 1454, loss = 0.8663)
# Saving model (epoch = 1455, loss = 0.8659)
# Saving model (epoch = 1463, loss = 0.8653)
# Saving model (epoch = 1480, loss = 0.8650)
# Saving model (epoch = 1490, loss = 0.8649)
# Saving model (epoch = 1496, loss = 0.8644)
# Saving model (epoch = 1511, loss = 0.8634)
# Saving model (epoch = 1517, loss = 0.8615)
# Saving model (epoch = 1550, loss = 0.8613)
# Saving model (epoch = 1554, loss = 0.8610)
# Saving model (epoch = 1574, loss = 0.8599)
# Saving model (epoch = 1583, loss = 0.8599)
# Saving model (epoch = 1593, loss = 0.8595)
# Saving model (epoch = 1611, loss = 0.8590)
# Saving model (epoch = 1625, loss = 0.8586)
# Saving model (epoch = 1642, loss = 0.8578)
# Saving model (epoch = 1646, loss = 0.8571)
# Saving model (epoch = 1656, loss = 0.8570)
# Saving model (epoch = 1675, loss = 0.8569)
# Saving model (epoch = 1682, loss = 0.8568)
# Saving model (epoch = 1683, loss = 0.8566)
# Saving model (epoch = 1684, loss = 0.8562)
# Saving model (epoch = 1702, loss = 0.8552)
# Saving model (epoch = 1703, loss = 0.8548)
# Saving model (epoch = 1730, loss = 0.8548)
# Saving model (epoch = 1741, loss = 0.8544)
# Saving model (epoch = 1748, loss = 0.8542)
# Saving model (epoch = 1750, loss = 0.8539)
# Saving model (epoch = 1765, loss = 0.8533)
# Saving model (epoch = 1783, loss = 0.8532)
# Saving model (epoch = 1784, loss = 0.8528)
# Saving model (epoch = 1794, loss = 0.8523)
# Saving model (epoch = 1810, loss = 0.8515)
# Saving model (epoch = 1855, loss = 0.8509)
# Saving model (epoch = 1858, loss = 0.8502)
# Saving model (epoch = 1882, loss = 0.8500)
# Saving model (epoch = 1921, loss = 0.8496)
# Saving model (epoch = 1928, loss = 0.8494)
# Saving model (epoch = 1932, loss = 0.8487)
# Saving model (epoch = 1956, loss = 0.8474)
# Saving model (epoch = 1966, loss = 0.8470)
# Saving model (epoch = 1996, loss = 0.8466)
# Saving model (epoch = 2021, loss = 0.8462)
# Saving model (epoch = 2022, loss = 0.8459)
# Saving model (epoch = 2029, loss = 0.8456)
# Saving model (epoch = 2066, loss = 0.8453)
# Saving model (epoch = 2067, loss = 0.8451)
# Saving model (epoch = 2117, loss = 0.8436)
# Saving model (epoch = 2156, loss = 0.8436)
# Saving model (epoch = 2169, loss = 0.8433)
# Saving model (epoch = 2179, loss = 0.8432)
# Saving model (epoch = 2186, loss = 0.8430)
# Saving model (epoch = 2201, loss = 0.8424)
# Saving model (epoch = 2205, loss = 0.8417)
# Saving model (epoch = 2223, loss = 0.8414)
# Saving model (epoch = 2265, loss = 0.8414)
# Saving model (epoch = 2295, loss = 0.8410)
# Saving model (epoch = 2309, loss = 0.8407)
# Saving model (epoch = 2315, loss = 0.8400)
# Saving model (epoch = 2328, loss = 0.8391)
# Saving model (epoch = 2329, loss = 0.8389)
# Saving model (epoch = 2335, loss = 0.8387)
# Saving model (epoch = 2464, loss = 0.8386)
# Saving model (epoch = 2485, loss = 0.8386)
# Saving model (epoch = 2497, loss = 0.8385)
# Saving model (epoch = 2501, loss = 0.8374)
# Saving model (epoch = 2512, loss = 0.8372)
# Saving model (epoch = 2532, loss = 0.8371)
# Saving model (epoch = 2566, loss = 0.8367)
# Saving model (epoch = 2577, loss = 0.8365)
# Saving model (epoch = 2578, loss = 0.8361)
# Saving model (epoch = 2587, loss = 0.8359)
# Saving model (epoch = 2588, loss = 0.8356)
# Saving model (epoch = 2605, loss = 0.8353)
# Saving model (epoch = 2641, loss = 0.8352)
# Saving model (epoch = 2671, loss = 0.8349)
# Saving model (epoch = 2683, loss = 0.8349)
# Saving model (epoch = 2712, loss = 0.8342)
# Saving model (epoch = 2777, loss = 0.8339)
# Saving model (epoch = 2821, loss = 0.8335)
# Saving model (epoch = 2919, loss = 0.8334)
# Saving model (epoch = 2931, loss = 0.8326)
# Saving model (epoch = 2949, loss = 0.8324)
# Saving model (epoch = 2950, loss = 0.8320)
# Saving model (epoch = 3017, loss = 0.8315)
# Saving model (epoch = 3021, loss = 0.8315)
# Saving model (epoch = 3035, loss = 0.8313)
# Saving model (epoch = 3064, loss = 0.8311)
# Saving model (epoch = 3093, loss = 0.8301)
# Saving model (epoch = 3117, loss = 0.8300)
# Saving model (epoch = 3146, loss = 0.8300)
# Saving model (epoch = 3193, loss = 0.8299)
# Saving model (epoch = 3200, loss = 0.8299)
# Saving model (epoch = 3223, loss = 0.8298)
# Saving model (epoch = 3280, loss = 0.8297)
# Saving model (epoch = 3281, loss = 0.8276)
# Finished training after 3482 epochs

# %%
plot_learning_curve(model_loss_record, title='deep model')

# %%
del model
model = NeuralNet(tr_set.dataset.dim).to(device)
ckpt = torch.load(config['save_path'], map_location='cpu')  # Load your best model
model.load_state_dict(ckpt)
plot_pred(dv_set, model, device)  # Show prediction on the validation set

# %% [markdown]
# ## **Testing**
# The predictions of your model on testing set will be stored at `pred.csv`.

# %%
def save_pred(preds, file):
    ''' Save predictions to specified file '''
    print('Saving results to {}'.format(file))
    with open(file, 'w') as fp:
        writer = csv.writer(fp)
        writer.writerow(['id', 'tested_positive'])
        for i, p in enumerate(preds):
            writer.writerow([i, p])

preds = test(tt_set, model, device)  # predict COVID-19 cases with your model
save_pred(preds, 'pred.csv')         # save prediction file to pred.csv
# Out:
# Saving results to pred.csv

# %% [markdown]
# ## **Reference**
# Source: Heng-Jui Chang @ NTUEE (https://github.com/ga642381/ML2021-Spring/blob/main/HW01/HW01.ipynb)
